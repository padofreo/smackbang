# %%
import pandas as pd

# %%
import requests
from requests.structures import CaseInsensitiveDict

url = "https://tequila-api.kiwi.com/v2/search"
headers = CaseInsensitiveDict()

fly_to = []

continent = 'asia'

if continent == 'asia':
    fly_to = ['SIN,KUL,HAN,DPS,HKT']
    

query_string = {'fly_from':'NRT,SYD', 'fly_to':fly_to,
                'date_from':'01/04/2022', 'date_to':'01/04/2022','return_from':'','<return_to':'', 
               'adults':1, 'children':0,'selected_cabins':'M','adult_hold_bag':1,'adult_hand_bag':1,
               "curr":'USD', 'limit':1000}

headers["accept"] = "application/json"
headers["apikey"] = "Ul0VynVifRdwPUGTkFU_Btfro1vyewb7"


resp = requests.get(url, headers=headers, params=query_string)

print(resp.status_code)
# Out:
# 200

# %%
fly_to
# Out:
# ['SIN,KUL,HAN,DPS,HKT']

# %%
d = resp.json()

# %%
d['data'][0]
# Out:
# {'id': '037218844a8b0000d238ba27_0',
#  'flyFrom': 'SYD',
#  'flyTo': 'SIN',
#  'cityFrom': 'Sydney',
#  'cityCodeFrom': 'SYD',
#  'cityTo': 'Singapore',
#  'cityCodeTo': 'SIN',
#  'countryFrom': {'code': 'AU', 'name': 'Australia'},
#  'countryTo': {'code': 'SG', 'name': 'Singapore'},
#  'type_flights': ['deprecated'],
#  'nightsInDest': None,
#  'quality': 320.999805,
#  'distance': 6301.43,
#  'duration': {'departure': 29700, 'return': 0, 'total': 29700},
#  'price': 269,
#  'conversion': {'USD': 269, 'EUR': 243},
#  'fare': {'adults': 269, 'children': 269, 'infants': 269},
#  'bags_price': {'1': 43.5},
#  'baglimit': {'hand_height': 38,
#   'hand_length': 54,
#   'hand_weight': 7,
#   'hand_width': 23,
#   'hold_dimensions_sum': 158,
#   'hold_height': 50,
#   'hold_length': 70,
#   'hold_weight': 20,
#   'hold_width': 38,
#   'personal_item_height': 30,
#   'personal_item_length': 40,
#   'personal_item_weight': 3,
#   'personal_item_width': 10},
#  'availability': {'seats': 8},
#  'routes': [['SYD', 'SIN']],
#  'airlines': ['TR'],
#  'route': [{'id': '037218844a8b0000d238ba27_0',
#    'combination_id': '037218844a8b0000d238ba27',
#    'flyFrom': 'SYD',
#    'flyTo': 'SIN',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Singapore',
#    'cityCodeTo': 'SIN',
#    'airline': 'TR',
#    'flight_no': 3,
#    'operating_carrier': 'TR',
#    'operating_flight_no': '3',
#    'fare_basis': 'O1TRAPID',
#    'fare_category': 'M',
#    'fare_classes': 'O',
#    'fare_family': '',
#    'return': 0,
#    'bags_recheck_required': False,
#    'vi_connection': False,
#    'guarantee': False,
#    'last_seen': '2022-03-02T21:32:32.000Z',
#    'refresh_timestamp': '2022-03-02T21:32:32.000Z',
#    'equipment': None,
#    'vehicle_type': 'aircraft',
#    'local_arrival': '2022-04-01T18:40:00.000Z',
#    'utc_arrival': '2022-04-01T10:40:00.000Z',
#    'local_departure': '2022-04-01T13:25:00.000Z',
#    'utc_departure': '2022-04-01T02:25:00.000Z'}],
#  'booking_token': 'D9wl_ieZD_ye0akU4DhhtQqqMLOGld36k3j4TTNwhdnxQ2AuKKkdfMHR3wS3hu4n1n2TBZku56DjbYGSpEX-DYKGV0t0BGyz8ueXh2y-yX9lreJpFlRcCzqI4c2GC_aH_vfHFpBKzBge3o7Z1tA0QohRzZO6jl-UrG_sU9yLui4Swi3L9VUrzoKGrD7xNcmWYokFJndu0tSgY8NGaOl84sJgDQTb6A4E_QmNqyF80tfx87o60H1QfR3DsrmaO9qCe9uQvBQpQGqpB4suPSkk6zPrjIdeek4goq7t4rq8hUbCUshEFLTgMnGg2Hj9viUZj3PNBmsTQanSfq756pXD1tHNDKddXXYanCHcs6NgSNLN6bI246Z_Nznu1FlW_Zm2EKGCc_mEenyrJ5U2tTIdE2X7T1QnSYtplEqK3h5CWXTavvBjDNMJMzIuU-hzRFk0f',
#  'deep_link': 'https://www.kiwi.com/deep?from=SYD&to=SIN&flightsId=037218844a8b0000d238ba27_0&price=243&passengers=1&affilid=leestevensmackbang2&lang=en&currency=USD&searchBags=1.1&booking_token=D9wl_ieZD_ye0akU4DhhtQqqMLOGld36k3j4TTNwhdnxQ2AuKKkdfMHR3wS3hu4n1n2TBZku56DjbYGSpEX-DYKGV0t0BGyz8ueXh2y-yX9lreJpFlRcCzqI4c2GC_aH_vfHFpBKzBge3o7Z1tA0QohRzZO6jl-UrG_sU9yLui4Swi3L9VUrzoKGrD7xNcmWYokFJndu0tSgY8NGaOl84sJgDQTb6A4E_QmNqyF80tfx87o60H1QfR3DsrmaO9qCe9uQvBQpQGqpB4suPSkk6zPrjIdeek4goq7t4rq8hUbCUshEFLTgMnGg2Hj9viUZj3PNBmsTQanSfq756pXD1tHNDKddXXYanCHcs6NgSNLN6bI246Z_Nznu1FlW_Zm2EKGCc_mEenyrJ5U2tTIdE2X7T1QnSYtplEqK3h5CWXTavvBjDNMJMzIuU-hzRFk0f',
#  'tracking_pixel': '',
#  'facilitated_booking_available': True,
#  'pnr_count': 1,
#  'has_airport_change': False,
#  'technical_stops': 0,
#  'throw_away_ticketing': False,
#  'hidden_city_ticketing': False,
#  'virtual_interlining': False,
#  'transfers': [],
#  'local_arrival': '2022-04-01T18:40:00.000Z',
#  'utc_arrival': '2022-04-01T10:40:00.000Z',
#  'local_departure': '2022-04-01T13:25:00.000Z',
#  'utc_departure': '2022-04-01T02:25:00.000Z'}

# %% [raw]
# response

# %%
for i in range(0,len(d['data'])):
    print(f"flight {i}: {d['data'][i]['cityFrom']} to {d['data'][i]['cityTo']}")
# Out:
# flight 0: Sydney to Singapore
# flight 1: Sydney to Singapore
# flight 2: Sydney to Singapore
# flight 3: Sydney to Kuala Lumpur
# flight 4: Sydney to Kuala Lumpur
# flight 5: Sydney to Kuala Lumpur
# flight 6: Sydney to Singapore
# flight 7: Sydney to Singapore
# flight 8: Sydney to Phuket City
# flight 9: Sydney to Phuket City
# flight 10: Sydney to Singapore
# flight 11: Sydney to Singapore
# flight 12: Sydney to Singapore
# flight 13: Sydney to Singapore
# flight 14: Sydney to Singapore
# flight 15: Sydney to Singapore
# flight 16: Sydney to Singapore
# flight 17: Sydney to Kuala Lumpur
# flight 18: Sydney to Kuala Lumpur
# flight 354: Sydney to Singapore
# flight 355: Tokyo to Hanoi
# flight 356: Sydney to Kuala Lumpur
# flight 357: Sydney to Singapore
# flight 358: Sydney to Singapore
# flight 359: Sydney to Singapore
# flight 360: Sydney to Singapore
# flight 361: Sydney to Singapore
# flight 362: Sydney to Singapore
# flight 363: Sydney to Singapore
# flight 364: Sydney to Singapore
# flight 365: Sydney to Kuala Lumpur
# flight 366: Sydney to Singapore
# flight 367: Sydney to Kuala Lumpur
# flight 368: Sydney to Kuala Lumpur
# flight 369: Sydney to Kuala Lumpur
# flight 370: Sydney to Singapore
# flight 371: Sydney to Singapore
# flight 372: Sydney to Kuala Lumpur
# flight 373: Sydney to Singapore
# flight 374: Sydney to Singapore
# flight 375: Sydney to Kuala Lumpur
# flight 376: Sydney to Kuala Lumpur
# flight 377: Sydney to Singapore
# flight 378: Sydney to Singapore
# flight 379: Sydney to Kuala Lumpur
# flight 380: Sydney to Kuala Lumpur
# flight 381: Sydney to Singapore
# flight 382: Sydney to Singapore
# flight 383: Sydney to Singapore
# flight 384: Sydney to Singapore

# %%
len(d['data'])
# Out:
# 385

# %%
d['data'][0].keys()
# Out:
# dict_keys(['id', 'flyFrom', 'flyTo', 'cityFrom', 'cityCodeFrom', 'cityTo', 'cityCodeTo', 'countryFrom', 'countryTo', 'type_flights', 'nightsInDest', 'quality', 'distance', 'duration', 'price', 'conversion', 'fare', 'bags_price', 'baglimit', 'availability', 'routes', 'airlines', 'route', 'booking_token', 'deep_link', 'tracking_pixel', 'facilitated_booking_available', 'pnr_count', 'has_airport_change', 'technical_stops', 'throw_away_ticketing', 'hidden_city_ticketing', 'virtual_interlining', 'transfers', 'local_arrival', 'utc_arrival', 'local_departure', 'utc_departure'])

# %%
df = {'cityFrom':[], 'cityTo':[],'cityCodeFrom':[],'cityCodeTo':[], 'price':[], 'duration':[],'total_stops':[],'distance':[],'local_departure':[],'local_arrival':[], "deep_link":[]}

# %%
d['data'][1]['booking_token']
# Out:
# 'Ds5gx27sY2yGkihwKG_bz44sUSG8SUj-2TaDlZwPNEP7_mqqm6ICdu0070isW3hRjOFzpygWAr3kr01qrDQ3n1-IdtzPk28an3nUJcnWeglSXF9PW95xXctoehl9YuhJaNUGJpXieb6WPW7fZ0GZfh5vahIF4SSBl-GPq8Oe4pwKAyaRUrz6FSYOWP4CGI68o9d6QbtpkZSZQ8q4Z2G0L22oIRx7rOKHYstoE-UBnV-oSnuh6ecIf7VregRdIxUg5_lxKYWquRvSfg8o10yW3vjOqOEifo5uALMGefJeUnUECsMkTbnnjvRF-0bCwioY1GyEzj2UMBPctvQtmW8_vSTSQYk4YMGqfh2hd7VDu4iqGtKa9NI85Rt9sylBCfoXPFFYq-FORcRUUeAs0ALvqQL9kpVBlRbj_UOTR8TnAhQ6xB5FCXTRIognctVuWcz5rgM2tc7pkOJfLS1a7OokqnxlcFQ-1mUP6zR50o1HttIyfr6972vpT_zkD6tzNCFpi'

# %%
for i in range(0,len(d['data'])):
    for k,v in d['data'][i].items():
        if k == 'duration':
            df[k].append(round(v['total']/3600,2))
        elif k == 'id':
            df['total_stops'].append(len(v.split('|'))-1)
        else:
            if k in df:
                df[k].append(v)

# %%
df = pd.DataFrame(df)

# %%
df.head()['deep_link']
# Out:
# 0    https://www.kiwi.com/deep?from=SYD&to=SIN&flig...
# 1    https://www.kiwi.com/deep?from=SYD&to=KUL&flig...
# 2    https://www.kiwi.com/deep?from=SYD&to=HKT&flig...
# 3    https://www.kiwi.com/deep?from=SYD&to=SIN&flig...
# 4    https://www.kiwi.com/deep?from=SYD&to=KUL&flig...
# Name: deep_link, dtype: object

# %%
df['route'] = df.cityCodeFrom + "-" + df.cityCodeTo

# %%
df.head()
# Out:
#   cityFrom        cityTo cityCodeFrom cityCodeTo  price  duration  \
# 0   Sydney     Singapore          SYD        SIN    466     16.00
# 1   Sydney     Singapore          SYD        SIN    466     16.00
# 2   Sydney     Singapore          SYD        SIN    482     13.92
# 3   Sydney  Kuala Lumpur          SYD        KUL    499     30.00
# 4   Sydney  Kuala Lumpur          SYD        KUL    499     30.00
#
#    total_stops  distance           local_departure             local_arrival  \
# 0            1   6301.43  2022-04-01T13:25:00.000Z  2022-04-01T18:40:00.000Z
# 1            1   6301.43  2022-04-01T13:25:00.000Z  2022-04-01T18:40:00.000Z
# 2            1   6301.43  2022-04-01T13:25:00.000Z  2022-04-01T18:40:00.000Z
# 3            2   6591.75  2022-04-01T13:25:00.000Z  2022-04-02T08:40:00.000Z
# 4            2   6591.75  2022-04-01T13:25:00.000Z  2022-04-02T08:40:00.000Z
#
#                                            deep_link    route
# 0  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...  SYD-SIN
# 1  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...  SYD-SIN
# 2  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...  SYD-SIN
# 3  https://www.kiwi.com/deep?from=SYD&to=KUL&flig...  SYD-KUL
# 4  https://www.kiwi.com/deep?from=SYD&to=KUL&flig...  SYD-KUL

# %%
df = df.groupby('route').min().sort_values('cityTo')

# %%
df
# Out:
#         cityFrom        cityTo cityCodeFrom cityCodeTo  price  duration  \
# route
# SYD-DPS   Sydney      Denpasar          SYD        DPS    892     29.58
# TYO-DPS    Tokyo      Denpasar          TYO        DPS    850     38.08
# TYO-HAN    Tokyo         Hanoi          TYO        HAN    650     12.00
# SYD-KUL   Sydney  Kuala Lumpur          SYD        KUL    499     14.50
# TYO-KUL    Tokyo  Kuala Lumpur          TYO        KUL    752     20.33
# SYD-HKT   Sydney   Phuket City          SYD        HKT    558     15.17
# TYO-HKT    Tokyo   Phuket City          TYO        HKT    738     14.75
# SYD-SIN   Sydney     Singapore          SYD        SIN    466     13.92
# TYO-SIN    Tokyo     Singapore          TYO        SIN    702     14.58
#
#          total_stops  distance           local_departure  \
# route
# SYD-DPS            3   4627.24  2022-04-01T07:00:00.000Z
# TYO-DPS            3   5616.76  2022-04-01T10:20:00.000Z
# TYO-HAN            1   3723.95  2022-04-01T09:15:00.000Z
# SYD-KUL            1   6591.75  2022-04-01T06:25:00.000Z
# TYO-KUL            2   5414.54  2022-04-01T19:00:00.000Z
# SYD-HKT            1   7275.70  2022-04-01T11:00:00.000Z
# TYO-HKT            2   5260.74  2022-04-01T10:20:00.000Z
# SYD-SIN            1   6301.43  2022-04-01T06:10:00.000Z
# TYO-SIN            1   5363.07  2022-04-01T10:20:00.000Z
#
#                     local_arrival  \
# route
# SYD-DPS  2022-04-02T12:05:00.000Z
# TYO-DPS  2022-04-02T12:05:00.000Z
# TYO-HAN  2022-04-01T13:35:00.000Z
# SYD-KUL  2022-04-01T21:35:00.000Z
# TYO-KUL  2022-04-02T08:40:00.000Z
# SYD-HKT  2022-04-01T16:30:00.000Z
# TYO-HKT  2022-04-01T19:05:00.000Z
# SYD-SIN  2022-04-01T16:50:00.000Z
# TYO-SIN  2022-04-01T20:25:00.000Z
#
#                                                  deep_link
# route
# SYD-DPS  https://www.kiwi.com/deep?from=SYD&to=DPS&flig...
# TYO-DPS  https://www.kiwi.com/deep?from=NRT&to=DPS&flig...
# TYO-HAN  https://www.kiwi.com/deep?from=NRT&to=HAN&flig...
# SYD-KUL  https://www.kiwi.com/deep?from=SYD&to=KUL&flig...
# TYO-KUL  https://www.kiwi.com/deep?from=NRT&to=KUL&flig...
# SYD-HKT  https://www.kiwi.com/deep?from=SYD&to=HKT&flig...
# TYO-HKT  https://www.kiwi.com/deep?from=NRT&to=HKT&flig...
# SYD-SIN  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...
# TYO-SIN  https://www.kiwi.com/deep?from=NRT&to=SIN&flig...

# %%
df = df.pivot(index='cityTo', columns='cityFrom', values=['price','duration','total_stops','distance','local_departure','local_arrival','deep_link'])

# %%
df['combined_price'] = df['price'].iloc[:,0] + df['price'].iloc[:,1]

# %%
df.sort_values(by='combined_price')
# Out:
#               price       duration        total_stops       distance           \
# cityFrom     Sydney Tokyo   Sydney  Tokyo      Sydney Tokyo   Sydney    Tokyo
# cityTo
# Singapore       466   702    13.92  14.58           1     1  6301.43  5363.07
# Kuala Lumpur    499   752     14.5  20.33           1     2  6591.75  5414.54
# Phuket City     558   738    15.17  14.75           1     2   7275.7  5260.74
# Denpasar        892   850    29.58  38.08           3     3  4627.24  5616.76
# Hanoi           NaN   650      NaN   12.0         NaN     1      NaN  3723.95
#
#                        local_departure                            \
# cityFrom                        Sydney                     Tokyo
# cityTo
# Singapore     2022-04-01T06:10:00.000Z  2022-04-01T10:20:00.000Z
# Kuala Lumpur  2022-04-01T06:25:00.000Z  2022-04-01T19:00:00.000Z
# Phuket City   2022-04-01T11:00:00.000Z  2022-04-01T10:20:00.000Z
# Denpasar      2022-04-01T07:00:00.000Z  2022-04-01T10:20:00.000Z
# Hanoi                              NaN  2022-04-01T09:15:00.000Z
#
#                          local_arrival                            \
# cityFrom                        Sydney                     Tokyo
# cityTo
# Singapore     2022-04-01T16:50:00.000Z  2022-04-01T20:25:00.000Z
# Kuala Lumpur  2022-04-01T21:35:00.000Z  2022-04-02T08:40:00.000Z
# Phuket City   2022-04-01T16:30:00.000Z  2022-04-01T19:05:00.000Z
# Denpasar      2022-04-02T12:05:00.000Z  2022-04-02T12:05:00.000Z
# Hanoi                              NaN  2022-04-01T13:35:00.000Z
#
#                                                       deep_link  \
# cityFrom                                                 Sydney
# cityTo
# Singapore     https://www.kiwi.com/deep?from=SYD&to=SIN&flig...
# Kuala Lumpur  https://www.kiwi.com/deep?from=SYD&to=KUL&flig...
# Phuket City   https://www.kiwi.com/deep?from=SYD&to=HKT&flig...
# Denpasar      https://www.kiwi.com/deep?from=SYD&to=DPS&flig...
# Hanoi                                                       NaN
#
#                                                                 combined_price
# cityFrom                                                  Tokyo
# cityTo
# Singapore     https://www.kiwi.com/deep?from=NRT&to=SIN&flig...           1168
# Kuala Lumpur  https://www.kiwi.com/deep?from=NRT&to=KUL&flig...           1251
# Phuket City   https://www.kiwi.com/deep?from=NRT&to=HKT&flig...           1296
# Denpasar      https://www.kiwi.com/deep?from=NRT&to=DPS&flig...           1742
# Hanoi         https://www.kiwi.com/deep?from=NRT&to=HAN&flig...            NaN

# %%
airports = pd.read_csv('../data/airport_codes.csv')

# %%
airports.head()
# Out:
#                                       city_airport  \
# 0                                  City or Airport
# 1                        Aalborg - Aalborg Airport
# 2  Albuquerque - Albuquerque International Sunport
# 3     Abuja - Nnamdi Azikiwe International Airport
# 4                 Aberdeen - Aberdeen Dyce Airport
#
#                            airport_name continent iso_country iso_region  \
# 0                                   NaN       NaN         NaN        NaN
# 1                       Aalborg Airport        EU          DK      DK-81
# 2     Albuquerque International Sunport       NaN          US      US-NM
# 3  Nnamdi Azikiwe International Airport        AF          NG      NG-FC
# 4                 Aberdeen Dyce Airport        EU          GB     GB-SCT
#
#           city gps_code iata_code        lat         lon  elevation_ft ident
# 0          NaN      NaN       NaN        NaN         NaN           NaN   NaN
# 1      Aalborg     EKYT       AAL  57.092759    9.849243          10.0  EKYT
# 2  Albuquerque     KABQ       ABQ  35.040199 -106.609001        5355.0  KABQ
# 3        Abuja     DNAA       ABV   9.006790    7.263170        1123.0  DNAA
# 4     Aberdeen     EGPD       ABZ  57.201900   -2.197780         215.0  EGPD

# %%
airports['continent'].value_counts()
# Out:
# EU    157
# AS    156
# AF     48
# SA     21
# OC     13
# Name: continent, dtype: int64

# %%
asian_codes = airports[airports['continent']=='AS']['iata_code'].dropna()

# %%
type(asian_codes)
# Out:
# pandas.core.series.Series

# %%
asian_codes
# Out:
# 7      ADA
# 8      ADB
# 18     ALA
# 21     ALP
# 23     AMM
#       ...
# 537    VDA
# 549    WNZ
# 551    WUH
# 552    XIY
# 553    XMN
# Name: iata_code, Length: 153, dtype: object

# %%
my_list = []
for code in asian_codes:
    my_list.append(code)

# %%
'NRT' in my_list
# Out:
# True

# %%
my_list.remove('NRT')

# %%
check_list = ','.join(my_list)

# %%
url = "https://tequila-api.kiwi.com/v2/search"
headers = CaseInsensitiveDict()

  

query_string = {'fly_from':'NRT,SYD', 'fly_to':check_list,
                'date_from':'01/04/2022', 'date_to':'01/04/2022','return_from':'','return_to':'', 
               'adults':1, 'children':0,'selected_cabins':'M','adult_hold_bag':1,'adult_hand_bag':1,
               "curr":'USD', 'limit':1000}

headers["accept"] = "application/json"
headers["apikey"] = "Ul0VynVifRdwPUGTkFU_Btfro1vyewb7"


resp2 = requests.get(url, headers=headers, params=query_string)

print(resp2.status_code)
# Out:
# 200

# %%
len(resp2.json()['data'])
# Out:
# 756
