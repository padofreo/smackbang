# %%
import pandas as pd

# %%
import requests
from requests.structures import CaseInsensitiveDict

url = "https://tequila-api.kiwi.com/v2/search"
headers = CaseInsensitiveDict()

fly_to = []

continent = 'asia'

if continent == 'asia':
    fly_to = ['SIN,KUL,HAN,DPS,HKT']
    

query_string = {'fly_from':'NRT,SYD', 'fly_to':fly_to,
                'date_from':'01/04/2022', 'date_to':'01/04/2022','return_from':'','return_to':'', 
               'adults':1, 'children':0,'selected_cabins':'M','adult_hold_bag':1,'adult_hand_bag':1,
               "curr":'USD', 'limit':1000}

headers["accept"] = "application/json"
headers["apikey"] = "Ul0VynVifRdwPUGTkFU_Btfro1vyewb7"


resp = requests.get(url, headers=headers, params=query_string)

print(resp.status_code)
# Out:
# 200

# %%
fly_to
# Out:
# ['SIN,KUL,HAN,DPS,HKT']

# %%
d = resp.json()

# %%
d
# Out:
# {'search_id': '5352e163-4bea-a814-35a4-dccd272a711b',
#  'time': 1,
#  'currency': 'USD',
#  'fx_rate': 1.120605,
#  'data': [{'id': '037218844a8b0000d238ba27_0',
#    'flyFrom': 'SYD',
#    'flyTo': 'SIN',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Singapore',
#    'cityCodeTo': 'SIN',
#    'countryFrom': {'code': 'AU', 'name': 'Australia'},
#    'countryTo': {'code': 'SG', 'name': 'Singapore'},
#    'type_flights': ['deprecated'],
#    'nightsInDest': None,
#    'quality': 318.999805,
#    'distance': 6301.43,
#    'duration': {'departure': 29700, 'return': 0, 'total': 29700},
#    'price': 270,
#    'conversion': {'USD': 270, 'EUR': 241},
#    'fare': {'adults': 270, 'children': 270, 'infants': 270},
#    'bags_price': {'1': 43.5},
#    'baglimit': {'hand_height': 38,
#     'hand_length': 54,
#     'hand_weight': 7,
#     'hand_width': 23,
#     'hold_dimensions_sum': 158,
#     'hold_height': 50,
#     'hold_length': 70,
#     'hold_weight': 20,
#     'hold_width': 38,
#     'personal_item_height': 30,
#     'personal_item_length': 40,
#     'personal_item_weight': 3,
#     'personal_item_width': 10},
#    'availability': {'seats': None},
#    'routes': [['SYD', 'SIN']],
#    'airlines': ['TR'],
#    'route': [{'id': '037218844a8b0000d238ba27_0',
#      'combination_id': '037218844a8b0000d238ba27',
#      'flyFrom': 'SYD',
#      'flyTo': 'SIN',
#      'cityFrom': 'Sydney',
#      'cityCodeFrom': 'SYD',
#      'cityTo': 'Singapore',
#      'cityCodeTo': 'SIN',
#      'airline': 'TR',
#      'flight_no': 3,
#      'operating_carrier': 'TR',
#      'operating_flight_no': '3',
#      'fare_basis': 'O1TRAPID',
#      'fare_category': 'M',
#      'fare_classes': 'O',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T06:34:05.000Z',
#      'refresh_timestamp': '2022-03-01T06:34:05.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T18:40:00.000Z',
#      'utc_arrival': '2022-04-01T10:40:00.000Z',
#      'local_departure': '2022-04-01T13:25:00.000Z',
#      'utc_departure': '2022-04-01T02:25:00.000Z'}],
#    'booking_token': 'D0lzMAOT-1PCPVeM0SONpk-ggipeWrXH2g3oPI9EbWiEUyk9IEwJCjxXkBL0la3ZT8E4xxw-wJdu_GBi_VltMqvH1NKb-LGhGxmM-GWYNBK-VwCacxXgBATSMGxxi0nrOBjlrTzQxxRA0SSyEWd-jSH2DlOpDHglWAW_8-Vju9q1XAHRJToMpb5j6dzumPqFu_icOwn27DuvMAatgkexsbxWSEM7RsoDmkjoj2U84ojNFSyV6QNU0yqAdMNq1o5z388RcMZG5BTZaryjypKwtAevbgE99hK7fHPWHKKqkfWzJWX4jOkbxWbraQ1iSGAUNzgK8nJ5s5RBd1JMQQMK4MdO60TApDqgDJ1WFZYzRkNRnWo151_iRD0fcNw8ctz8f-rYreNRnr_LldAjA1qCV5xe4rlkEBTSJ6_ENHzDx4LfQEtuid8zm7KgyZHltMX9T',
#    'deep_link': 'https://www.kiwi.com/deep?from=SYD&to=SIN&flightsId=037218844a8b0000d238ba27_0&price=241&passengers=1&affilid=leestevensmackbang2&lang=en&currency=USD&searchBags=1.1&booking_token=D0lzMAOT-1PCPVeM0SONpk-ggipeWrXH2g3oPI9EbWiEUyk9IEwJCjxXkBL0la3ZT8E4xxw-wJdu_GBi_VltMqvH1NKb-LGhGxmM-GWYNBK-VwCacxXgBATSMGxxi0nrOBjlrTzQxxRA0SSyEWd-jSH2DlOpDHglWAW_8-Vju9q1XAHRJToMpb5j6dzumPqFu_icOwn27DuvMAatgkexsbxWSEM7RsoDmkjoj2U84ojNFSyV6QNU0yqAdMNq1o5z388RcMZG5BTZaryjypKwtAevbgE99hK7fHPWHKKqkfWzJWX4jOkbxWbraQ1iSGAUNzgK8nJ5s5RBd1JMQQMK4MdO60TApDqgDJ1WFZYzRkNRnWo151_iRD0fcNw8ctz8f-rYreNRnr_LldAjA1qCV5xe4rlkEBTSJ6_ENHzDx4LfQEtuid8zm7KgyZHltMX9T',
#    'tracking_pixel': '',
#    'facilitated_booking_available': True,
#    'pnr_count': 1,
#    'has_airport_change': False,
#    'technical_stops': 0,
#    'throw_away_ticketing': False,
#    'hidden_city_ticketing': False,
#    'virtual_interlining': False,
#    'transfers': [],
#    'local_arrival': '2022-04-01T18:40:00.000Z',
#    'utc_arrival': '2022-04-01T10:40:00.000Z',
#    'local_departure': '2022-04-01T13:25:00.000Z',
#    'utc_departure': '2022-04-01T02:25:00.000Z'},
#   {'id': '037210ff4a8b00006126e4aa_0|037210ff4a8b00006126e4aa_1',
#    'flyFrom': 'SYD',
#    'flyTo': 'KUL',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Kuala Lumpur',
#    'cityCodeTo': 'KUL',
#    'countryFrom': {'code': 'AU', 'name': 'Australia'},
#    'countryTo': {'code': 'MY', 'name': 'Malaysia'},
#    'type_flights': ['deprecated'],
#    'nightsInDest': None,
#    'quality': 449.999525,
#    'distance': 6591.75,
#    'duration': {'departure': 80100, 'return': 0, 'total': 80100},
#    'price': 292,
#    'conversion': {'USD': 292, 'EUR': 260},
#    'fare': {'adults': 292, 'children': 292, 'infants': 292},
#    'bags_price': {'1': 67.5},
#    'baglimit': {'hand_height': 38,
#     'hand_length': 54,
#     'hand_weight': 7,
#     'hand_width': 23,
#     'hold_dimensions_sum': 158,
#     'hold_height': 50,
#     'hold_length': 70,
#     'hold_weight': 20,
#     'hold_width': 38,
#     'personal_item_height': 30,
#     'personal_item_length': 40,
#     'personal_item_weight': 3,
#     'personal_item_width': 10},
#    'availability': {'seats': 5},
#    'routes': [['SYD', 'KUL']],
#    'airlines': ['TR'],
#    'route': [{'id': '037210ff4a8b00006126e4aa_0',
#      'combination_id': '037210ff4a8b00006126e4aa',
#      'flyFrom': 'SYD',
#      'flyTo': 'SIN',
#      'cityFrom': 'Sydney',
#      'cityCodeFrom': 'SYD',
#      'cityTo': 'Singapore',
#      'cityCodeTo': 'SIN',
#      'airline': 'TR',
#      'flight_no': 3,
#      'operating_carrier': 'TR',
#      'operating_flight_no': '3',
#      'fare_basis': 'X1TRODMA',
#      'fare_category': 'M',
#      'fare_classes': 'X',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T07:09:36.000Z',
#      'refresh_timestamp': '2022-03-01T07:09:36.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T18:40:00.000Z',
#      'utc_arrival': '2022-04-01T10:40:00.000Z',
#      'local_departure': '2022-04-01T13:25:00.000Z',
#      'utc_departure': '2022-04-01T02:25:00.000Z'},
#     {'id': '037210ff4a8b00006126e4aa_1',
#      'combination_id': '037210ff4a8b00006126e4aa',
#      'flyFrom': 'SIN',
#      'flyTo': 'KUL',
#      'cityFrom': 'Singapore',
#      'cityCodeFrom': 'SIN',
#      'cityTo': 'Kuala Lumpur',
#      'cityCodeTo': 'KUL',
#      'airline': 'TR',
#      'flight_no': 456,
#      'operating_carrier': 'TR',
#      'operating_flight_no': '456',
#      'fare_basis': 'X1TRODMA',
#      'fare_category': 'M',
#      'fare_classes': 'X',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T07:09:36.000Z',
#      'refresh_timestamp': '2022-03-01T07:09:36.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-02T08:40:00.000Z',
#      'utc_arrival': '2022-04-02T00:40:00.000Z',
#      'local_departure': '2022-04-02T07:25:00.000Z',
#      'utc_departure': '2022-04-01T23:25:00.000Z'}],
#    'booking_token': 'Dqn9n2yAD2OOXfTq0IetvNYNw1wYhQlBnuE6n9tozb5l9WMNpAY5IgiHbWpCrqhAYgx0kzTdcmXtgcfDVBgyrnK5Iearbx9UbWpaPy2Ko0BXO-K2Pa8KIbo2HTzfYvPa44DlvwIYn7KYlmi5Vf8_xzwPd5JGQ1JIT9wJ6gCxyNW7Othu9KWHut05DUeEd_OZPFbko0ASdDI7BcjZ7ioZGwnVlsvJeHjxxv08hnjTGv4_PHl9WNpY9wlr_I32jubaYM7mb6MS4Bomrdv4ojpAoo2d7MaA3gGgywkedg-Z9PTs7fayTGGF5Uim-j4PQ7SlidPslYNmJfycsnrVqmd2knEUpvnPbUSpOdDwGiRYkCoURdegVmNW1XHw4a9Idb6s2YOR9FBWlpe2oWRAw_aEp1n3MkW0_XyY5kvhpzOjtG2aRRNdKaaA0wF9nlKCkrvS3X579UCNK_M8E5vpdBXJZyfe2DXyM_4_sfga0HuLibAU=',
#    'deep_link': 'https://www.kiwi.com/deep?from=SYD&to=KUL&flightsId=037210ff4a8b00006126e4aa_0%7C037210ff4a8b00006126e4aa_1&price=260&passengers=1&affilid=leestevensmackbang2&lang=en&currency=USD&searchBags=1.1&booking_token=Dqn9n2yAD2OOXfTq0IetvNYNw1wYhQlBnuE6n9tozb5l9WMNpAY5IgiHbWpCrqhAYgx0kzTdcmXtgcfDVBgyrnK5Iearbx9UbWpaPy2Ko0BXO-K2Pa8KIbo2HTzfYvPa44DlvwIYn7KYlmi5Vf8_xzwPd5JGQ1JIT9wJ6gCxyNW7Othu9KWHut05DUeEd_OZPFbko0ASdDI7BcjZ7ioZGwnVlsvJeHjxxv08hnjTGv4_PHl9WNpY9wlr_I32jubaYM7mb6MS4Bomrdv4ojpAoo2d7MaA3gGgywkedg-Z9PTs7fayTGGF5Uim-j4PQ7SlidPslYNmJfycsnrVqmd2knEUpvnPbUSpOdDwGiRYkCoURdegVmNW1XHw4a9Idb6s2YOR9FBWlpe2oWRAw_aEp1n3MkW0_XyY5kvhpzOjtG2aRRNdKaaA0wF9nlKCkrvS3X579UCNK_M8E5vpdBXJZyfe2DXyM_4_sfga0HuLibAU=',
#    'tracking_pixel': '',
#    'facilitated_booking_available': True,
#    'pnr_count': 1,
#    'has_airport_change': False,
#    'technical_stops': 0,
#    'throw_away_ticketing': False,
#    'hidden_city_ticketing': False,
#    'virtual_interlining': False,
#    'transfers': [],
#    'local_arrival': '2022-04-02T08:40:00.000Z',
#    'utc_arrival': '2022-04-02T00:40:00.000Z',
#    'local_departure': '2022-04-01T13:25:00.000Z',
#    'utc_departure': '2022-04-01T02:25:00.000Z'},
#   {'id': '037223654a8b0000bc3fd31f_0|037223654a8b0000bc3fd31f_1',
#    'flyFrom': 'SYD',
#    'flyTo': 'HKT',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Phuket City',
#    'cityCodeTo': 'HKT',
#    'countryFrom': {'code': 'AU', 'name': 'Australia'},
#    'countryTo': {'code': 'TH', 'name': 'Thailand'},
#    'type_flights': ['deprecated'],
#    'nightsInDest': None,
#    'quality': 547.999295,
#    'distance': 7275.7,
#    'duration': {'departure': 121500, 'return': 0, 'total': 121500},
#    'price': 298,
#    'conversion': {'USD': 298, 'EUR': 266},
#    'fare': {'adults': 298, 'children': 298, 'infants': 298},
#    'bags_price': {'1': 67.5},
#    'baglimit': {'hand_height': 38,
#     'hand_length': 54,
#     'hand_weight': 7,
#     'hand_width': 23,
#     'hold_dimensions_sum': 158,
#     'hold_height': 50,
#     'hold_length': 70,
#     'hold_weight': 20,
#     'hold_width': 38,
#     'personal_item_height': 30,
#     'personal_item_length': 40,
#     'personal_item_weight': 3,
#     'personal_item_width': 10},
#    'availability': {'seats': 2},
#    'routes': [['SYD', 'HKT']],
#    'airlines': ['TR'],
#    'route': [{'id': '037223654a8b0000bc3fd31f_0',
#      'combination_id': '037223654a8b0000bc3fd31f',
#      'flyFrom': 'SYD',
#      'flyTo': 'SIN',
#      'cityFrom': 'Sydney',
#      'cityCodeFrom': 'SYD',
#      'cityTo': 'Singapore',
#      'cityCodeTo': 'SIN',
#      'airline': 'TR',
#      'flight_no': 3,
#      'operating_carrier': 'TR',
#      'operating_flight_no': '3',
#      'fare_basis': 'X1TRODMA',
#      'fare_category': 'M',
#      'fare_classes': 'X',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T06:44:39.000Z',
#      'refresh_timestamp': '2022-03-01T06:44:39.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T18:40:00.000Z',
#      'utc_arrival': '2022-04-01T10:40:00.000Z',
#      'local_departure': '2022-04-01T13:25:00.000Z',
#      'utc_departure': '2022-04-01T02:25:00.000Z'},
#     {'id': '037223654a8b0000bc3fd31f_1',
#      'combination_id': '037223654a8b0000bc3fd31f',
#      'flyFrom': 'SIN',
#      'flyTo': 'HKT',
#      'cityFrom': 'Singapore',
#      'cityCodeFrom': 'SIN',
#      'cityTo': 'Phuket City',
#      'cityCodeTo': 'HKT',
#      'airline': 'TR',
#      'flight_no': 652,
#      'operating_carrier': 'TR',
#      'operating_flight_no':

#     'hand_weight': 7,
#     'hand_width': 23,
#     'hold_dimensions_sum': 158,
#     'hold_height': 52,
#     'hold_length': 78,
#     'hold_weight': 15,
#     'hold_width': 28,
#     'personal_item_height': 30,
#     'personal_item_length': 40,
#     'personal_item_weight': 5,
#     'personal_item_width': 10},
#    'availability': {'seats': 2},
#    'routes': [['SYD', 'SIN']],
#    'airlines': ['QF', 'JQ'],
#    'route': [{'id': '0372077b4a8b0000d55c24b3_0',
#      'combination_id': '0372077b4a8b0000d55c24b3',
#      'flyFrom': 'SYD',
#      'flyTo': 'MEL',
#      'cityFrom': 'Sydney',
#      'cityCodeFrom': 'SYD',
#      'cityTo': 'Melbourne',
#      'cityCodeTo': 'MEL',
#      'airline': 'QF',
#      'flight_no': 421,
#      'operating_carrier': 'QF',
#      'operating_flight_no': '421',
#      'fare_basis': '',
#      'fare_category': 'M',
#      'fare_classes': '',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T07:02:57.000Z',
#      'refresh_timestamp': '2022-03-01T07:02:57.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T09:50:00.000Z',
#      'utc_arrival': '2022-03-31T22:50:00.000Z',
#      'local_departure': '2022-04-01T08:15:00.000Z',
#      'utc_departure': '2022-03-31T21:15:00.000Z'},
#     {'id': '077b18844a8b0000d6ef789d_0',
#      'combination_id': '077b18844a8b0000d6ef789d',
#      'flyFrom': 'MEL',
#      'flyTo': 'SIN',
#      'cityFrom': 'Melbourne',
#      'cityCodeFrom': 'MEL',
#      'cityTo': 'Singapore',
#      'cityCodeTo': 'SIN',
#      'airline': 'JQ',
#      'flight_no': 7,
#      'operating_carrier': 'JQ',
#      'operating_flight_no': '7',
#      'fare_basis': 'ELECOE5',
#      'fare_category': 'M',
#      'fare_classes': 'E',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': True,
#      'vi_connection': True,
#      'guarantee': True,
#      'last_seen': '2022-03-01T05:14:36.000Z',
#      'refresh_timestamp': '2022-03-01T05:14:36.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T17:50:00.000Z',
#      'utc_arrival': '2022-04-01T09:50:00.000Z',
#      'local_departure': '2022-04-01T13:00:00.000Z',
#      'utc_departure': '2022-04-01T02:00:00.000Z'}],
#    'booking_token': 'DBK5b7EJXeJj9UvpmrkKgm0x9wq5kw1u3ltbh5u-usX7sclWAI9lDi6IylX4bBklVe0YkJzGmAQPmVRzRFBAgpqAumEyBKmK9a9X_qHbSsR9S6O9U9uI36gPOQ16zBJAOYtR3qLJNLlbiJ--FSlMeM_x9QI3eOCyTL2cocdUlPQZ_mBwEczhktGBunj8FkpJQ8WlUV9UOxQZavugCEpVjzwIJe2bd8a7M15s8CUZT9BlORKQshABqUcIdG66_o_K0tTEX8cvl8CLp42lu29BgFmoOm2ys5lWM9wmE28KAs5JT0nkeXqofjT7HX8GfuG49j7LCgsjgpNJn0-n4r56fMM8h3xUpSLQSlxXbt76G78KJXSSl5RnIkBFFTiFai_HjefEjsEuoqgcNsRER4miwQuCGeL06Ux1LWO1NTweJfO49evjUbAkjgooBFXHBDrRZ7af-W4vBpV2fCxtB1j1Di9sW70WxqMJwNW-lv_ZQze-xnctQ-Pjj4YsWCbw8nX2uUm9RHxXC1ywlJy44Qt9gpQ==',
#    'deep_link': 'https://www.kiwi.com/deep?from=SYD&to=SIN&flightsId=0372077b4a8b0000d55c24b3_0%7C077b18844a8b0000d6ef789d_0&price=305&passengers=1&affilid=leestevensmackbang2&lang=en&currency=USD&searchBags=1.1&booking_token=DBK5b7EJXeJj9UvpmrkKgm0x9wq5kw1u3ltbh5u-usX7sclWAI9lDi6IylX4bBklVe0YkJzGmAQPmVRzRFBAgpqAumEyBKmK9a9X_qHbSsR9S6O9U9uI36gPOQ16zBJAOYtR3qLJNLlbiJ--FSlMeM_x9QI3eOCyTL2cocdUlPQZ_mBwEczhktGBunj8FkpJQ8WlUV9UOxQZavugCEpVjzwIJe2bd8a7M15s8CUZT9BlORKQshABqUcIdG66_o_K0tTEX8cvl8CLp42lu29BgFmoOm2ys5lWM9wmE28KAs5JT0nkeXqofjT7HX8GfuG49j7LCgsjgpNJn0-n4r56fMM8h3xUpSLQSlxXbt76G78KJXSSl5RnIkBFFTiFai_HjefEjsEuoqgcNsRER4miwQuCGeL06Ux1LWO1NTweJfO49evjUbAkjgooBFXHBDrRZ7af-W4vBpV2fCxtB1j1Di9sW70WxqMJwNW-lv_ZQze-xnctQ-Pjj4YsWCbw8nX2uUm9RHxXC1ywlJy44Qt9gpQ==',
#    'tracking_pixel': '',
#    'facilitated_booking_available': True,
#    'pnr_count': 2,
#    'has_airport_change': False,
#    'technical_stops': 0,
#    'throw_away_ticketing': False,
#    'hidden_city_ticketing': False,
#    'virtual_interlining': True,
#    'transfers': [],
#    'local_arrival': '2022-04-01T17:50:00.000Z',
#    'utc_arrival': '2022-04-01T09:50:00.000Z',
#    'local_departure': '2022-04-01T08:15:00.000Z',
#    'utc_departure': '2022-03-31T21:15:00.000Z'},
#   {'id': '0372077b4a8b00006d11e7e9_0|077b18844a8c00003badb0d8_0',
#    'flyFrom': 'SYD',
#    'flyTo': 'SIN',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Singapore',
#    'cityCodeTo': 'SIN',
#    'countryFrom': {'code': 'AU', 'name': 'Australia'},
#    'countryTo': {'code': 'SG', 'name': 'Singapore'},
#    'type_flights': ['deprecated'],
#    'nightsInDest': None,
#    'quality': 599.332615,
#    'distance': 6301.43,
#    'duration': {'departure': 123900, 'return': 0, 'total': 123900},
#    'price': 349,
#    'conversion': {'USD': 349, 'EUR': 312},
#    'fare': {'adults': 349, 'children': 349, 'infants': 349},
#    'bags_price': {'1': 63.5},
#    'baglimit': {'hand_height': 34,
#     'hand_length': 48,
#     'hand_weight': 7,
#     'hand_width': 23,
#     'hold_dimensions_sum': 158,
#     'hold_height': 50,
#     'hold_length': 70,
#     'hold_weight': 15,
#     'hold_width': 38},
#    'availability': {'seats': 4},
#    'routes': [['SYD', 'SIN']],
#    'airlines': ['TR', 'ZL'],
#    'route': [{'id': '0372077b4a8b00006d11e7e9_0',
#      'combination_id': '0372077b4a8b00006d11e7e9',
#      'flyFrom': 'SYD',
#      'flyTo': 'MEL',
#      'cityFrom': 'Sydney',
#      'cityCodeFrom': 'SYD',
#      'cityTo': 'Melbourne',
#      'cityCodeTo': 'MEL',
#      'airline': 'ZL',
#      'flight_no': 169,
#      'operating_carrier': 'ZL',
#      'operating_flight_no': '169',
#      'fare_basis': '',
#      'fare_category': 'M',
#      'fare_classes': '',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T05:37:48.000Z',
#      'refresh_timestamp': '2022-03-01T05:37:48.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T22:05:00.000Z',
#      'utc_arrival': '2022-04-01T11:05:00.000Z',
#      'local_departure': '2022-04-01T20:30:00.000Z',
#      'utc_departure': '2022-04-01T09:30:00.000Z'},
#     {'id': '077b18844a8c00003badb0d8_0',
#      'combination_id': '077b18844a8c00003badb0d8',
#      'flyFrom': 'MEL',
#      'flyTo': 'SIN',
#      'cityFrom': 'Melbourne',
#      'cityCodeFrom': 'MEL',
#      'cityTo': 'Singapore',
#      'cityCodeTo': 'SIN',
#      'airline': 'TR',
#      'flight_no': 25,
#      'operating_carrier': 'TR',
#      'operating_flight_no': '25',
#      'fare_basis': 'O1TRAPID',
#      'fare_category': 'M',
#      'fare_classes': 'O',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': True,
#      'vi_connection': True,
#      'guarantee': True,
#      'last_seen': '2022-03-01T06:44:37.000Z',
#      'refresh_timestamp': '2022-03-01T06:44:37.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-03T03:55:00.000Z',
#      'utc_arrival': '2022-04-02T19:55:00.000Z',
#      'local_departure': '2022-04-02T22:45:00.000Z',
#      'utc_departure': '2022-04-02T11:45:00.000Z'}],
1',
#    'flyFrom': 'SYD',
#    'flyTo': 'HKT',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Phuket City',
#    'cityCodeTo': 'HKT',
#    'countryFrom': {'code': 'AU', 'name': 'Australia'},
#    'countryTo': {'code': 'TH', 'name': 'Thailand'},
#    'type_flights': ['deprecated'],
#    'nightsInDest': None,
#    'quality': 739.99894,
#    'distance': 7275.7,
#    'duration': {'departure': 185400, 'return': 0, 'total': 185400},
#    'price': 354,
#    'conversion': {'USD': 354, 'EUR': 316},
#    'fare': {'adults': 354, 'children': 354, 'infants': 354},
#    'bags_price': {'1': 87.5},
#    'baglimit': {'hand_height': 34,
#     'hand_length': 48,
#     'hand_weight': 7,
#     'hand_width': 23,
#     'hold_dimensions_sum': 158,
#     'hold_height': 50,
#     'hold_length': 70,
#     'hold_weight': 15,
#     'hold_width': 38},
#    'availability': {'seats': 4},
#    'routes': [['SYD', 'HKT']],
#    'airlines': ['TR', 'ZL'],
#    'route': [{'id': '0372077b4a8b00006d11e7e9_0',
#      'combination_id': '0372077b4a8b00006d11e7e9',
#      'flyFrom': 'SYD',
#      'flyTo': 'MEL',
#      'cityFrom': 'Sydney',
#      'cityCodeFrom': 'SYD',
#      'cityTo': 'Melbourne',
#      'cityCodeTo': 'MEL',
#      'airline': 'ZL',
#      'flight_no': 169,
#      'operating_carrier': 'ZL',
#      'operating_flight_no': '169',
#      'fare_basis': '',
#      'fare_category': 'M',
#      'fare_classes': '',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T05:37:48.000Z',
#      'refresh_timestamp': '2022-03-01T05:37:48.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T22:05:00.000Z',
#      'utc_arrival': '2022-04-01T11:05:00.000Z',
#      'local_departure': '2022-04-01T20:30:00.000Z',
#      'utc_departure': '2022-04-01T09:30:00.000Z'},
#     {'id': '077b23654a8c0000542d8dc5_0',
#      'combination_id': '077b23654a8c0000542d8dc5',
#      'flyFrom': 'MEL',
#      'flyTo': 'SIN',
#      'cityFrom': 'Melbourne',
#      'cityCodeFrom': 'MEL',
#      'cityTo': 'Singapore',
#      'cityCodeTo': 'SIN',
#      'airline': 'TR',
#      'flight_no': 25,
#      'operating_carrier': 'TR',
#      'operating_flight_no': '25',
#      'fare_basis': 'O1TRODMA',
#      'fare_category': 'M',
#      'fare_classes': 'O',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': True,
#      'vi_connection': True,
#      'guarantee': True,
#      'last_seen': '2022-03-01T06:27:51.000Z',
#      'refresh_timestamp': '2022-03-01T06:27:51.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-03T03:55:00.000Z',
#      'utc_arrival': '2022-04-02T19:55:00.000Z',
#      'local_departure': '2022-04-02T22:45:00.000Z',
#      'utc_departure': '2022-04-02T11:45:00.000Z'},
#     {'id': '077b23654a8c0000542d8dc5_1',
#      'combination_id': '077b23654a8c0000542d8dc5',
#      'flyFrom': 'SIN',
#      'flyTo': 'HKT',
#      'cityFrom': 'Singapore',
#      'cityCodeFrom': 'SIN',
#      'cityTo': 'Phuket City',
#      'cityCodeTo': 'HKT',
#      'airline': 'TR',
#      'flight_no': 652,
#      'operating_carrier': 'TR',
#      'operating_flight_no': '652',
#      'fare_basis': 'O1TRODMA',
#      'fare_category': 'M',
#      'fare_classes': 'O',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T06:27:51.000Z',
#      'refresh_timestamp': '2022-03-01T06:27:51.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-03T20:00:00.000Z',
#      'utc_arrival': '2022-04-03T13:00:00.000Z',
#      'local_departure': '2022-04-03T19:10:00.000Z',
#      'utc_departure': '2022-04-03T11:10:00.000Z'}],
#    'booking_token': 'DFcFkMK9DXmDVK4rrn_zrbvHZ76qZTWBaQS3WUpWfco3EbH94je1pPrabULcZAzEx3ojlXzPmTIipZUKkLSwfIepJN0fef0AoFpj_MBbxCTx98E97WGwa2SdNITivWe9zt835_QjIQDdcrboMdITVGW6jDOKPeDC52dRZmv_xfx54a7xfIvvvV46C2jeey8QQa5rSdr70FIfi5uhrmuRjP9sQJQp_5NXLNnw5L6sgFtB_C6F1pwzUm8XlQ1USOTZ_oIUL0US8PrteJysrMQBQ
0',
#    'flyFrom': 'SYD',
#    'flyTo': 'SIN',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Singapore',
#    'cityCodeTo': 'SIN',
#    'countryFrom': {'code': 'AU', 'name': 'Australia'},
#    'countryTo': {'code': 'SG', 'name': 'Singapore'},
#    'type_flights': ['deprecated'],
#    'nightsInDest': None,
#    'quality': 571.66607,
#    'distance': 6301.43,
#    'duration': {'departure': 102000, 'return': 0, 'total': 102000},
#    'price': 374,
#    'conversion': {'USD': 374, 'EUR': 333},
#    'fare': {'adults': 374, 'children': 374, 'infants': 374},
#    'bags_price': {'1': 66.89},
#    'baglimit': {'hand_height': 36,
#     'hand_length': 54,
#     'hand_weight': 7,
#     'hand_width': 23,
#     'hold_dimensions_sum': 158,
#     'hold_height': 50,
#     'hold_length': 70,
#     'hold_weight': 15,
#     'hold_width': 38,
#     'personal_item_height': 30,
#     'personal_item_length': 40,
#     'personal_item_weight': 3,
#     'personal_item_width': 10},
#    'availability': {'seats': 2},
#    'routes': [['SYD', 'SIN']],
#    'airlines': ['TR', 'JQ'],
#    'route': [{'id': '037209e44a8b0000a40cf6ca_0',
#      'combination_id': '037209e44a8b0000a40cf6ca',
#      'flyFrom': 'SYD',
#      'flyTo': 'OOL',
#      'cityFrom': 'Sydney',
#      'cityCodeFrom': 'SYD',
#      'cityTo': 'Gold Coast',
#      'cityCodeTo': 'OOL',
#      'airline': 'JQ',
#      'flight_no': 410,
#      'operating_carrier': 'JQ',
#      'operating_flight_no': '410',
#      'fare_basis': 'HLECOH',
#      'fare_category': 'M',
#      'fare_classes': 'H',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T06:13:35.000Z',
#      'refresh_timestamp': '2022-03-01T06:13:35.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T14:50:00.000Z',
#      'utc_arrival': '2022-04-01T04:50:00.000Z',
#      'local_departure': '2022-04-01T14:30:00.000Z',
#      'utc_departure': '2022-04-01T03:30:00.000Z'},
#     {'id': '09e418844a8c000036f3f4a9_0',
#      'combination_id': '09e418844a8c000036f3f4a9',
#      'flyFrom': 'OOL',
#      'flyTo': 'SIN',
#      'cityFrom': 'Gold Coast',
#      'cityCodeFrom': 'OOL',
#      'cityTo': 'Singapore',
#      'cityCodeTo': 'SIN',
#      'airline': 'TR',
#      'flight_no': 7,
#      'operating_carrier': 'TR',
#      'operating_flight_no': '7',
#      'fare_basis': 'N1TRAPID',
#      'fare_category': 'M',
#      'fare_classes': 'N',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': True,
#      'vi_connection': True,
#      'guarantee': True,
#      'last_seen': '2022-03-01T06:42:18.000Z',
#      'refresh_timestamp': '2022-03-01T06:42:18.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-02T15:50:00.000Z',
#      'utc_arrival': '2022-04-02T07:50:00.000Z',
#      'local_departure': '2022-04-02T09:30:00.000Z',
#      'utc_departure': '2022-04-01T23:30:00.000Z'}],
#    'booking_token': 'DcwF9XhGnyJ6HelxU_ihG0qDiAEfd3NsnZQuoTHkHfL05T2T9ROZNgZrD7plWtXq0WvdzYXB5KhQBsfYl5mXK3sEmUqpXXWFH3HDNWveNveccI6oWoIDnjER4JkIthRRlhxmeqOAOadlzQL5hE52DczuI8OgVaHCbSBQUSXxxcumwUEuq6siRC3MocW7nFaiQTGvZi22EFVkGV5cZL9nqRSFZl-wAHmGuQmEzv4sfCOUvAKs3rklSgYrPK3Si5E7OgP_7-h0HRsFH3vxDGVGMTrJQMuAL60838-IAwF2VUwZee1FeOETbQs-nhXDmJrjq6WCv2r_jpJN9fnXrET4zUXjr87N2c8kKFdXDLP9Y7us1Guuo-3vO3EpYCWdzJ_gSO2XKfQF2RcV4ls_4MAlD9SgJ5Xa8pArysfCSwgJKMjCq9yWuHl7ybmxkMcS64Pvf0HQTuRDd9TiowQ5xWNS_rhonYrHLZaGGR-bGpWQI30X93oZU9Twobo8XXouYdrEryNGoCRO4__4P5RS34DlDyA==',
#    'deep_link': 'https://www.kiwi.com/deep?from=SYD&to=SIN&flightsId=037209e44a8b0000a40cf6ca_0%7C09e418844a8c000036f3f4a9_0&price=333&passengers=1&affilid=leestevensmackbang2&lang=en&currency=USD&searchBags=1.1&booking_token=DcwF9XhGnyJ6HelxU_ihG0qDiAEfd3NsnZQuoTHkHfL05T2T9ROZNgZrD7plWtXq0WvdzYXB5KhQBsfYl5mXK3sEmUqpXXWFH3HDNWveNveccI6oWoIDnjER4JkIthRRlhxmeqOAOadlzQL5hE52DczuI8OgVaHCbSBQUSXxxcumwUEuq6siRC3MocW7nFaiQTGvZi22EFVkGV5cZL9nqRSFZl-wAHmGuQmEzv4sfCOUvAKs3rklSgYrPK3Si5E7OgP_7-h0HRsFH3vxDGVGMTrJQMuAL60838-IAwF2VUwZee1FeOETbQs-nhXDmJrjq6WCv2r_jpJN9fnXrET4zUXjr87N2c8kKFdXDLP9Y7us1Guuo-3vO3EpYCWdzJ_gSO2XKfQF2RcV4ls_4MAlD9SgJ5Xa8pArysfCSwgJKMjCq9yWuHl7ybmxkMcS64Pvf0HQTuRDd9TiowQ5xWNS_rhonYrHLZaGGR-bGpWQI30X93oZU9Twobo8XXouYdrEryNGoCRO4__4P5RS34DlDyA==',
#    'tracking_pixel': '',
#    'facilitated_booking_available': True,
#    'pnr_count': 2,
#    'has_airport_change': False,
#    'technical_stops': 0,
#    'throw_away_ticketing': False,
#    'hidden_city_ticketing': False,
#    'virtual_interlining': True,
#    'transfers': [],
#    'local_arrival': '2022-04-02T15:50:00.000Z',
#    'utc_arrival': '2022-04-02T07:50:00.000Z',
#    'local_departure': '2022-04-01T14:30:00.000Z',
#    'utc_departure': '2022-04-01T03:30:00.000Z'},
#   {'id': '0372077b4a8b00006d11e7e9_0|077b10ff4a8c0000a219e9b3_0|077b10ff4a8c0000a219e9b3_1',
#    'flyFrom': 'SYD',
#    'flyTo': 'KUL',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Kuala Lumpur',
#    'cityCodeTo': 'KUL',
#    'countryFrom': {'code': 'AU', 'name': 'Australia'},
#    'countryTo': {'code': 'MY', 'name': 'Malaysia'},
#    'type_flights': ['deprecated'],
#    'nightsInDest': None,
#    'quality': 753.665615,
#    'distance': 6591.75,
#    'duration': {'departure': 183900, 'return': 0, 'total': 183900},
#    'price': 373,
#    'conversion': {'EUR': 333, 'USD': 373},
#    'fare': {'adults': 373, 'children': 373, 'infants': 373},
#    'bags_price': {'1': 87.5},
#    'baglimit': {'hand_height': 34,
#     'hand_length': 48,
#     'hand_weight': 7,
#     'hand_width': 23,
#     'hold_dimensions_sum': 158,
#     'hold_height': 50,
#     'hold_length': 70,
#     'hold_weight': 15,
#     'hold_width': 38},
#    'availability': {'seats': 4},
#    'routes': [['SYD', 'KUL']],
#    'airlines': ['TR', 'ZL'],
#    'route': [{'id': '0372077b4a8b00006d11e7e9_0',
#      'combination_id': '0372077b4a8b00006d11e7e9',
#      'flyFrom': 'SYD',
#      'flyTo': 'MEL',
#      'cityFrom': 'Sydney',
#      'cityCodeFrom': 'SYD',
#      'cityTo': 'Melbourne',
#      'cityCodeTo': 'MEL',
#      'airline': 'ZL',
#      'flight_no': 169,
#      'operating_carrier': 'ZL',
#      'operating_flight_no': '169',
#      'fare_basis': '',
#      'fare_category': 'M',
#      'fare_classes': '',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T05:37:48.000Z',
#      'refresh_timestamp': '2022-03-01T05:37:48.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T22:05:00.000Z',
#      'utc_arrival': '2022-04-01T11:05:00.000Z',
#      'local_departure': '2022-04-01T20:30:00.000Z',
#      'utc_departure': '2022-04-01T09:30:00.000Z'},
#     {'id': '077b10ff4a8c0000a219e9b3_0',
#      'combination_id': '077b10ff4a8c0000a219e9b3',
#      'flyFrom': 'MEL',
#      'flyTo': 'SIN',
#      'cityFrom': 'Melbourne',
#      'cityCodeFrom': 'MEL',
#      'cityTo': 'Singapore',
#      'cityCodeTo': 'SIN',
#      'airline': 'TR',
#      'flight_no': 25,
#      'operating_carrier': 'TR',
#      'operating_flight_no': '25',
#      'fare_basis': 'X1TRODMA',
#      'fare_category': 'M',
#      'fare_classes': 'X',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': True,
#      'vi_connection': True,
#      'guarantee': True,
#      'last_seen': '2022-03-01T06:40:37.000Z',
#      'refresh_timestamp': '2022-03-01T06:40:37.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04

#    'pnr_count': 2,
#    'has_airport_change': False,
#    'technical_stops': 0,
#    'throw_away_ticketing': False,
#    'hidden_city_ticketing': False,
#    'virtual_interlining': True,
#    'transfers': [],
#    'local_arrival': '2022-04-03T16:45:00.000Z',
#    'utc_arrival': '2022-04-03T08:45:00.000Z',
#    'local_departure': '2022-04-01T22:30:00.000Z',
#    'utc_departure': '2022-04-01T13:30:00.000Z'},
#   {'id': '03721c394a8b00000bcf6ec0_0|03721c394a8b00000bcf6ec0_1|1c3910ff4a8b00005dce152d_0|1c3910ff4a8b00005dce152d_1',
#    'flyFrom': 'SYD',
#    'flyTo': 'KUL',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Kuala Lumpur',
#    'cityCodeTo': 'KUL',
#    'countryFrom': {'code': 'AU', 'name': 'Australia'},
#    'countryTo': {'code': 'MY', 'name': 'Malaysia'},
#    'type_flights': ['deprecated'],
#    'nightsInDest': None,
#    'quality': 2174.66592,
#    'distance': 6591.75,
#    'duration': {'departure': 129000, 'return': 0, 'total': 129000},
#    'price': 2103,
#    'conversion': {'USD': 2103, 'EUR': 1876},
#    'fare': {'adults': 2103, 'children': 2103, 'infants': 2103},
#    'bags_price': {'1': 0},
#    'baglimit': {'hand_height': 37,
#     'hand_length': 50,
#     'hand_weight': 7,
#     'hand_width': 20,
#     'hold_dimensions_sum': 150,
#     'hold_height': 50,
#     'hold_length': 75,
#     'hold_weight': 20,
#     'hold_width': 25},
#    'availability': {'seats': None},
#    'routes': [['SYD', 'KUL']],
#    'airlines': ['EK', 'QR'],
#    'route': [{'id': '03721c394a8b00000bcf6ec0_0',
#      'combination_id': '03721c394a8b00000bcf6ec0',
#      'flyFrom': 'SYD',
#      'flyTo': 'DXB',
#      'cityFrom': 'Sydney',
#      'cityCodeFrom': 'SYD',
#      'cityTo': 'Dubai',
#      'cityCodeTo': 'DXB',
#      'airline': 'EK',
#      'flight_no': 415,
#      'operating_carrier': 'EK',
#      'operating_flight_no': '415',
#      'fare_basis': 'BLSOSAU1',
#      'fare_category': 'M',
#      'fare_classes': 'B',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T06:53:24.000Z',
#      'refresh_timestamp': '2022-03-01T06:53:24.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T13:20:00.000Z',
#      'utc_arrival': '2022-04-01T09:20:00.000Z',
#      'local_departure': '2022-04-01T06:00:00.000Z',
#      'utc_departure': '2022-03-31T19:00:00.000Z'},
#     {'id': '03721c394a8b00000bcf6ec0_1',
#      'combination_id': '03721c394a8b00000bcf6ec0',
#      'flyFrom': 'DXB',
#      'flyTo': 'IKA',
#      'cityFrom': 'Dubai',
#      'cityCodeFrom': 'DXB',
#      'cityTo': 'Tehran',
#      'cityCodeTo': 'THR',
#      'airline': 'EK',
#      'flight_no': 979,
#      'operating_carrier': 'EK',
#      'operating_flight_no': '979',
#      'fare_basis': 'BLSOSAU1',
#      'fare_category': 'M',
#      'fare_classes': 'B',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T06:53:24.000Z',
#      'refresh_timestamp': '2022-03-01T06:53:24.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T17:40:00.000Z',
#      'utc_arrival': '2022-04-01T13:10:00.000Z',
#      'local_departure': '2022-04-01T15:00:00.000Z',
#      'utc_departure': '2022-04-01T11:00:00.000Z'},
#     {'id': '1c3910ff4a8b00005dce152d_0',
#      'combination_id': '1c3910ff4a8b00005dce152d',
#      'flyFrom': 'IKA',
#      'flyTo': 'DOH',
#      'cityFrom': 'Tehran',
#      'cityCodeFrom': 'THR',
#      'cityTo': 'Doha',
#      'cityCodeTo': 'DOH',
#      'airline': 'QR',
#      'flight_no': 499,
#      'operating_carrier': 'QR',
#      'operating_flight_no': '499',
#      'fare_basis': 'NLIRR1RO',
#      'fare_category': 'M',
#      'fare_classes': 'N',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': True,
#      'vi_connection': True,
#      'guarantee': True,
#      'last_seen': '2022-03-01T04:14:17.000Z',
#      'refresh_timestamp': '2022-03-01T04:14:17.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-02
I3P8UR6CgwoyNVH7ODgzF3Yq4AdBV6qKJb7bi1WCUeynigCO_R_k-VJQm4QvXSU_iSF2es0j8rfuHWaPtxH1ky_cyw_5T12i6_l0LGLearF8TdJFARysbr0-wVnjezPRPU7BePKcb6YE5t2muPNpOc0avTmH5wrm9mEvVG3kasGRCo7X6ctCGcfb27r0-qHDHaGnJ6VI6aJKR44zad4Qo0NCQSW3U0Q5FQJtKjG6CgVHA-X-oZjxi2pqMJq_NwsSW4f2uAjdc458BNUNOSABAjgHMON7nxAKlSR8aqSFXnie8K1btNMVgsPz2OKpA==',
#    'tracking_pixel': '',
#    'facilitated_booking_available': False,
#    'pnr_count': 2,
#    'has_airport_change': False,
#    'technical_stops': 0,
#    'throw_away_ticketing': False,
#    'hidden_city_ticketing': False,
#    'virtual_interlining': True,
#    'transfers': [],
#    'local_arrival': '2022-04-02T14:50:00.000Z',
#    'utc_arrival': '2022-04-02T06:50:00.000Z',
#    'local_departure': '2022-04-01T06:00:00.000Z',
#    'utc_departure': '2022-03-31T19:00:00.000Z'},
#   {'id': '03721c394a8b00000bcf6ec0_0|03721c394a8b00000bcf6ec0_1|1c3923654a8b00008ae5badd_0|1c3923654a8b00008ae5badd_1',
#    'flyFrom': 'SYD',
#    'flyTo': 'HKT',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Phuket City',
#    'cityCodeTo': 'HKT',
#    'countryFrom': {'code': 'AU', 'name': 'Australia'},
#    'countryTo': {'code': 'TH', 'name': 'Thailand'},
#    'type_flights': ['deprecated'],
#    'nightsInDest': None,
#    'quality': 2256.99926,
#    'distance': 7275.7,
#    'duration': {'departure': 127800, 'return': 0, 'total': 127800},
#    'price': 2197,
#    'conversion': {'USD': 2197, 'EUR': 1961},
#    'fare': {'adults': 2197, 'children': 2197, 'infants': 2197},
#    'bags_price': {'1': 0},
#    'baglimit': {'hand_height': 37,
#     'hand_length': 50,
#     'hand_weight': 7,
#     'hand_width': 20,
#     'hold_dimensions_sum': 150,
#     'hold_height': 50,
#     'hold_length': 75,
#     'hold_weight': 20,
#     'hold_width': 25},
#    'availability': {'seats': 1},
#    'routes': [['SYD', 'HKT']],
#    'airlines': ['EK', 'QR'],
#    'route': [{'id': '03721c394a8b00000bcf6ec0_0',
#      'combination_id': '03721c394a8b00000bcf6ec0',
#      'flyFrom': 'SYD',
#      'flyTo': 'DXB',
#      'cityFrom': 'Sydney',
#      'cityCodeFrom': 'SYD',
#      'cityTo': 'Dubai',
#      'cityCodeTo': 'DXB',
#      'airline': 'EK',
#      'flight_no': 415,
#      'operating_carrier': 'EK',
#      'operating_flight_no': '415',
#      'fare_basis': 'BLSOSAU1',
#      'fare_category': 'M',
#      'fare_classes': 'B',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T06:53:24.000Z',
#      'refresh_timestamp': '2022-03-01T06:53:24.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T13:20:00.000Z',
#      'utc_arrival': '2022-04-01T09:20:00.000Z',
#      'local_departure': '2022-04-01T06:00:00.000Z',
#      'utc_departure': '2022-03-31T19:00:00.000Z'},
#     {'id': '03721c394a8b00000bcf6ec0_1',
#      'combination_id': '03721c394a8b00000bcf6ec0',
#      'flyFrom': 'DXB',
#      'flyTo': 'IKA',
#      'cityFrom': 'Dubai',
#      'cityCodeFrom': 'DXB',
#      'cityTo': 'Tehran',
#      'cityCodeTo': 'THR',
#      'airline': 'EK',
#      'flight_no': 979,
#      'operating_carrier': 'EK',
#      'operating_flight_no': '979',
#      'fare_basis': 'BLSOSAU1',
#      'fare_category': 'M',
#      'fare_classes': 'B',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T06:53:24.000Z',
#      'refresh_timestamp': '2022-03-01T06:53:24.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-01T17:40:00.000Z',
#      'utc_arrival': '2022-04-01T13:10:00.000Z',
#      'local_departure': '2022-04-01T15:00:00.000Z',
#      'utc_departure': '2022-04-01T11:00:00.000Z'},
#     {'id': '1c3923654a8b00008ae5badd_0',
#      'combination_id': '1c3923654a8b00008ae5badd',
#      'flyFrom': 'IKA',
#      'flyTo': 'DOH',
#      'cityFrom': 'Tehran',
#      'cityCodeFrom': 'THR',
#      'cityTo': 'Doha',
#      'cityCodeTo': 'DOH',
#      'airline': 'QR',
#      'flight_no': 499,
#      'operating_carrier': 'QR',
#      'operating_flight_no': '499',
#      'fare_basis': 'NLIRR1RO',
#      'fare_category': 'M',
#      'fare_classes': 'N',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': True,
#      'vi_connection': True,
#      'guarantee': True,
#      'last_seen': '2022-03-01T06:28:32.000Z',
#      'refresh_timestamp': '1970-01-01T00:00:00.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-02T00:20:00.000Z',
#      'utc_arrival': '2022-04-01T21:20:00.000Z',
#      'local_departure': '2022-04-01T23:45:00.000Z',
#      'utc_departure': '2022-04-01T19:15:00.000Z'},
#     {'id': '1c3923654a8b00008ae5badd_1',
#      'combination_id': '1c3923654a8b00008ae5badd',
#      'flyFrom': 'DOH',
#      'flyTo': 'HKT',
#      'cityFrom': 'Doha',
#      'cityCodeFrom': 'DOH',
#      'cityTo': 'Phuket City',
#      'cityCodeTo': 'HKT',
#      'airline': 'QR',
#      'flight_no': 840,
#      'operating_carrier': 'QR',
#      'operating_flight_no': '840',
#      'fare_basis': 'NLIRR1RO',
#      'fare_category': 'M',
#      'fare_classes': 'N',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'last_seen': '2022-03-01T06:28:32.000Z',
#      'refresh_timestamp': '1970-01-01T00:00:00.000Z',
#      'equipment': None,
#      'vehicle_type': 'aircraft',
#      'local_arrival': '2022-04-02T13:30:00.000Z',
#      'utc_arrival': '2022-04-02T06:30:00.000Z',
#      'local_departure': '2022-04-02T02:55:00.000Z',
#      'utc_departure': '2022-04-01T23:55:00.000Z'}],
#    'booking_token': 'D3k3rJt3790SIgIoKKzPzmP4gUmarFyeK7iI9yJ1owFL_bPRLbCrPUZlGHoD8yFUrpSFP3Z753-gK-FLHtNpNxX70EyTjufVN5BsUZQfLvoJXxCjdwgtPFqSCg5u6j8tRNb1g7jbgsF4wCkvvFF75WuxPK-ae5D06aVMjGJWRiOihbNtjI41twXhUzjKx-0OHAPzWDZjxAyk_PbDEZiuSPpW7G8c3_wzNb-4TvL5q8Q9jFGw5gOiTUGvZwaqAk4snN4y6sO8bM7QxKiLoaZJLz9PsOTW72frqFea7Laih-1DOX_YhcYIJIprZwI_FGbfUM6_loUv3qcahAVb-feaHTq-TyJkn1lT14ftnzU5gga5HSOiBhV1psYpV6y7ZI5grK9BWPMXzGSJmEcYXlt6eoXVWXjz5o-emvbdbbWhMUpqIxxrAA10pFxUkHkqVoelK822A5yuKffVHsYxGW2IjFakhi81SDITR95S2KueMhvLZgezItStnFnCUmMYtz4zHcLe92UAlt6bdPXBYlz5jECKImV80xWCSgzgk7IZo3pMJZ3GEV_80XX6WoDgM1F3Xo-1bJZ8kYO_Zz8_ydPOsP2oY6z1lgeKyech7y4yJW7F83A7rCimSq_QmpkeasuKJ',
#    'deep_link': 'https://www.kiwi.com/deep?from=SYD&to=HKT&flightsId=03721c394a8b00000bcf6ec0_0%7C03721c394a8b00000bcf6ec0_1%7C1c3923654a8b00008ae5badd_0%7C1c3923654a8b00008ae5badd_1&price=1961&passengers=1&affilid=leestevensmackbang2&lang=en&currency=USD&searchBags=1.1&booking_token=D3k3rJt3790SIgIoKKzPzmP4gUmarFyeK7iI9yJ1owFL_bPRLbCrPUZlGHoD8yFUrpSFP3Z753-gK-FLHtNpNxX70EyTjufVN5BsUZQfLvoJXxCjdwgtPFqSCg5u6j8tRNb1g7jbgsF4wCkvvFF75WuxPK-ae5D06aVMjGJWRiOihbNtjI41twXhUzjKx-0OHAPzWDZjxAyk_PbDEZiuSPpW7G8c3_wzNb-4TvL5q8Q9jFGw5gOiTUGvZwaqAk4snN4y6sO8bM7QxKiLoaZJLz9PsOTW72frqFea7Laih-1DOX_YhcYIJIprZwI_FGbfUM6_loUv3qcahAVb-feaHTq-TyJkn1lT14ftnzU5gga5HSOiBhV1psYpV6y7ZI5grK9BWPMXzGSJmEcYXlt6eoXVWXjz5o-emvbdbbWhMUpqIxxrAA10pFxUkHkqVoelK822A5yuKffVHsYxGW2IjFakhi81SDITR95S2KueMhvLZgezItStnFnCUmMYtz4zHcLe92UAlt6bdPXBYlz5jECKImV80xWCSgzgk7IZo3pMJZ3GEV_80XX6WoDgM1F3Xo-1bJZ8kYO_Zz8_ydPOsP2oY6z1lgeKyech7y4yJW7F83A7rCimSq_QmpkeasuKJ',
#    'tracking_pixel': '',
#    'facilitated_booking_available': False,
#    'pnr_count': 2,
#    'has_airport_change': False,
#    'technical_stops': 0,
#    'throw_away_ticketing': False,
#    'hidden_city_ticketing': False,
#    'virtual_interlining': True,
#    'transfers': [],
#    'local_arrival': '2022-04-02T13:30:00.000Z',
#    'utc_arrival': '2022-04-02T06:30:00.000Z',
#    'local_departure': '2022-04-01T06:00:00.000Z',
#    'utc_departure': '2022-03-31T19:00:00.000Z'}],
#  '_results': 160,
#  'search_params': {'flyFrom_type': 'airport',
#   'to_type': 'airport',
#   'seats': {'passengers': 1, 'adults': 1, 'children': 0, 'infants': 0}},
#  'all_airlines': [],
#  'all_stopover_airports': [],
#  'del': 0,
#  'currency_rate': 0.892375,
#  'connections': [],
#  'refresh': [],
#  'ref_tasks': [],
#  'sort_version': 0}

# %% [raw]
# response

# %%
for i in range(0,len(d['data'])):
    print(f"flight {i}: {d['data'][i]['cityFrom']} to {d['data'][i]['cityTo']}")
# Out:
# flight 0: Sydney to Singapore
# flight 1: Sydney to Kuala Lumpur
# flight 2: Sydney to Phuket City
# flight 3: Sydney to Singapore
# flight 4: Sydney to Singapore
# flight 5: Sydney to Singapore
# flight 94: Tokyo to Phuket City
# flight 95: Tokyo to Singapore
# flight 96: Tokyo to Singapore
# flight 97: Tokyo to Phuket City
# flight 98: Tokyo to Singapore
# flight 99: Tokyo to Singapore
# flight 100: Tokyo to Singapore
# flight 101: Tokyo to Kuala Lumpur
# flight 102: Tokyo to Singapore
# flight 103: Tokyo to Phuket City
# flight 104: Tokyo to Singapore
# flight 105: Tokyo to Phuket City
# flight 106: Tokyo to Kuala Lumpur
# flight 107: Tokyo to Kuala Lumpur
# flight 108: Tokyo to Kuala Lumpur
# flight 109: Tokyo to Singapore
# flight 110: Tokyo to Singapore
# flight 111: Tokyo to Singapore
# flight 112: Tokyo to Kuala Lumpur
# flight 113: Tokyo to Hanoi
# flight 114: Tokyo to Hanoi
# flight 115: Tokyo to Hanoi
# flight 116: Tokyo to Kuala Lumpur
# flight 117: Tokyo to Singapore
# flight 118: Tokyo to Singapore
# flight 119: Tokyo to Hanoi
# flight 120: Tokyo to Hanoi
# flight 121: Tokyo to Denpasar
# flight 122: Tokyo to Kuala Lumpur
# flight 123: Tokyo to Hanoi
# flight 124: Tokyo to Hanoi
# flight 125: Tokyo to Denpasar
# flight 126: Tokyo to Kuala Lumpur
# flight 127: Tokyo to Denpasar
# flight 128: Tokyo to Phuket City
# flight 129: Tokyo to Denpasar
# flight 130: Sydney to Singapore
# flight 131: Tokyo to Kuala Lumpur
# flight 132: Tokyo to Phuket City
# flight 133: Tokyo to Kuala Lumpur
# flight 134: Tokyo to Phuket City
# flight 135: Tokyo to Hanoi
# flight 136: Tokyo to Hanoi
# flight 137: Sydney to Singapore
# flight 138: Sydney to Singapore
# flight 139: Tokyo to Kuala Lumpur
# flight 140: Sydney to Kuala Lumpur
# flight 141: Tokyo to Kuala Lumpur
# flight 142: Sydney to Kuala Lumpur
# flight 143: Tokyo to Hanoi
# flight 144: Tokyo to Hanoi
# flight 145: Tokyo to Singapore
# flight 146: Tokyo to Kuala Lumpur
# flight 147: Tokyo to Denpasar
# flight 148: Tokyo to Kuala Lumpur
# flight 149: Tokyo to Hanoi
# flight 150: Tokyo to Denpasar
# flight 151: Tokyo to Hanoi
# flight 152: Tokyo to Hanoi
# flight 153: Tokyo to Kuala Lumpur
# flight 154: Tokyo to Kuala Lumpur
# flight 155: Tokyo to Singapore
# flight 156: Tokyo to Singapore
# flight 157: Tokyo to Denpasar
# flight 158: Sydney to Kuala Lumpur
# flight 159: Sydney to Phuket City

# %%
len(d['data'])
# Out:
# 160

# %%
d['data'][0].keys()
# Out:
# dict_keys(['id', 'flyFrom', 'flyTo', 'cityFrom', 'cityCodeFrom', 'cityTo', 'cityCodeTo', 'countryFrom', 'countryTo', 'type_flights', 'nightsInDest', 'quality', 'distance', 'duration', 'price', 'conversion', 'fare', 'bags_price', 'baglimit', 'availability', 'routes', 'airlines', 'route', 'booking_token', 'deep_link', 'tracking_pixel', 'facilitated_booking_available', 'pnr_count', 'has_airport_change', 'technical_stops', 'throw_away_ticketing', 'hidden_city_ticketing', 'virtual_interlining', 'transfers', 'local_arrival', 'utc_arrival', 'local_departure', 'utc_departure'])

# %%
df = {'cityFrom':[], 'cityTo':[],'cityCodeFrom':[],'cityCodeTo':[], 'price':[], 'duration':[],'total_stops':[],'distance':[],'local_departure':[],'local_arrival':[], "deep_link":[]}

# %%
d['data'][1]
# Out:
# {'id': '037210ff4a8b00006126e4aa_0|037210ff4a8b00006126e4aa_1',
#  'flyFrom': 'SYD',
#  'flyTo': 'KUL',
#  'cityFrom': 'Sydney',
#  'cityCodeFrom': 'SYD',
#  'cityTo': 'Kuala Lumpur',
#  'cityCodeTo': 'KUL',
#  'countryFrom': {'code': 'AU', 'name': 'Australia'},
#  'countryTo': {'code': 'MY', 'name': 'Malaysia'},
#  'type_flights': ['deprecated'],
#  'nightsInDest': None,
#  'quality': 449.999525,
#  'distance': 6591.75,
#  'duration': {'departure': 80100, 'return': 0, 'total': 80100},
#  'price': 292,
#  'conversion': {'USD': 292, 'EUR': 260},
#  'fare': {'adults': 292, 'children': 292, 'infants': 292},
#  'bags_price': {'1': 67.5},
#  'baglimit': {'hand_height': 38,
#   'hand_length': 54,
#   'hand_weight': 7,
#   'hand_width': 23,
#   'hold_dimensions_sum': 158,
#   'hold_height': 50,
#   'hold_length': 70,
#   'hold_weight': 20,
#   'hold_width': 38,
#   'personal_item_height': 30,
#   'personal_item_length': 40,
#   'personal_item_weight': 3,
#   'personal_item_width': 10},
#  'availability': {'seats': 5},
#  'routes': [['SYD', 'KUL']],
#  'airlines': ['TR'],
#  'route': [{'id': '037210ff4a8b00006126e4aa_0',
#    'combination_id': '037210ff4a8b00006126e4aa',
#    'flyFrom': 'SYD',
#    'flyTo': 'SIN',
#    'cityFrom': 'Sydney',
#    'cityCodeFrom': 'SYD',
#    'cityTo': 'Singapore',
#    'cityCodeTo': 'SIN',
#    'airline': 'TR',
#    'flight_no': 3,
#    'operating_carrier': 'TR',
#    'operating_flight_no': '3',
#    'fare_basis': 'X1TRODMA',
#    'fare_category': 'M',
#    'fare_classes': 'X',
#    'fare_family': '',
#    'return': 0,
#    'bags_recheck_required': False,
#    'vi_connection': False,
#    'guarantee': False,
#    'last_seen': '2022-03-01T07:09:36.000Z',
#    'refresh_timestamp': '2022-03-01T07:09:36.000Z',
#    'equipment': None,
#    'vehicle_type': 'aircraft',
#    'local_arrival': '2022-04-01T18:40:00.000Z',
#    'utc_arrival': '2022-04-01T10:40:00.000Z',
#    'local_departure': '2022-04-01T13:25:00.000Z',
#    'utc_departure': '2022-04-01T02:25:00.000Z'},
#   {'id': '037210ff4a8b00006126e4aa_1',
#    'combination_id': '037210ff4a8b00006126e4aa',
#    'flyFrom': 'SIN',
#    'flyTo': 'KUL',
#    'cityFrom': 'Singapore',
#    'cityCodeFrom': 'SIN',
#    'cityTo': 'Kuala Lumpur',
#    'cityCodeTo': 'KUL',
#    'airline': 'TR',
#    'flight_no': 456,
#    'operating_carrier': 'TR',
#    'operating_flight_no': '456',
#    'fare_basis': 'X1TRODMA',
#    'fare_category': 'M',
#    'fare_classes': 'X',
#    'fare_family': '',
#    'return': 0,
#    'bags_recheck_required': False,
#    'vi_connection': False,
#    'guarantee': False,
#    'last_seen': '2022-03-01T07:09:36.000Z',
#    'refresh_timestamp': '2022-03-01T07:09:36.000Z',
#    'equipment': None,
#    'vehicle_type': 'aircraft',
#    'local_arrival': '2022-04-02T08:40:00.000Z',
#    'utc_arrival': '2022-04-02T00:40:00.000Z',
#    'local_departure': '2022-04-02T07:25:00.000Z',
#    'utc_departure': '2022-04-01T23:25:00.000Z'}],
#  'booking_token': 'Dqn9n2yAD2OOXfTq0IetvNYNw1wYhQlBnuE6n9tozb5l9WMNpAY5IgiHbWpCrqhAYgx0kzTdcmXtgcfDVBgyrnK5Iearbx9UbWpaPy2Ko0BXO-K2Pa8KIbo2HTzfYvPa44DlvwIYn7KYlmi5Vf8_xzwPd5JGQ1JIT9wJ6gCxyNW7Othu9KWHut05DUeEd_OZPFbko0ASdDI7BcjZ7ioZGwnVlsvJeHjxxv08hnjTGv4_PHl9WNpY9wlr_I32jubaYM7mb6MS4Bomrdv4ojpAoo2d7MaA3gGgywkedg-Z9PTs7fayTGGF5Uim-j4PQ7SlidPslYNmJfycsnrVqmd2knEUpvnPbUSpOdDwGiRYkCoURdegVmNW1XHw4a9Idb6s2YOR9FBWlpe2oWRAw_aEp1n3MkW0_XyY5kvhpzOjtG2aRRNdKaaA0wF9nlKCkrvS3X579UCNK_M8E5vpdBXJZyfe2DXyM_4_sfga0HuLibAU=',
#  'deep_link': 'https://www.kiwi.com/deep?from=SYD&to=KUL&flightsId=037210ff4a8b00006126e4aa_0%7C037210ff4a8b00006126e4aa_1&price=260&passengers=1&affilid=leestevensmackbang2&lang=en&currency=USD&searchBags=1.1&booking_token=Dqn9n2yAD2OOXfTq0IetvNYNw1wYhQlBnuE6n9tozb5l9WMNpAY5IgiHbWpCrqhAYgx0kzTdcmXtgcfDVBgyrnK5Iearbx9UbWpaPy2Ko0BXO-K2Pa8KIbo2HTzfYvPa44DlvwIYn7KYlmi5Vf8_xzwPd5JGQ1JIT9wJ6gCxyNW7Othu9KWHut05DUeEd_OZPFbko0ASdDI7BcjZ7ioZGwnVlsvJeHjxxv08hnjTGv4_PHl9WNpY9wlr_I32jubaYM7mb6MS4Bomrdv4ojpAoo2d7MaA3gGgywkedg-Z9PTs7fayTGGF5Uim-j4PQ7SlidPslYNmJfycsnrVqmd2knEUpvnPbUSpOdDwGiRYkCoURdegVmNW1XHw4a9Idb6s2YOR9FBWlpe2oWRAw_aEp1n3MkW0_XyY5kvhpzOjtG2aRRNdKaaA0wF9nlKCkrvS3X579UCNK_M8E5vpdBXJZyfe2DXyM_4_sfga0HuLibAU=',
#  'tracking_pixel': '',
#  'facilitated_booking_available': True,
#  'pnr_count': 1,
#  'has_airport_change': False,
#  'technical_stops': 0,
#  'throw_away_ticketing': False,
#  'hidden_city_ticketing': False,
#  'virtual_interlining': False,
#  'transfers': [],
#  'local_arrival': '2022-04-02T08:40:00.000Z',
#  'utc_arrival': '2022-04-02T00:40:00.000Z',
#  'local_departure': '2022-04-01T13:25:00.000Z',
#  'utc_departure': '2022-04-01T02:25:00.000Z'}

# %%
for i in range(0,len(d['data'])):
    for k,v in d['data'][i].items():
        if k == 'duration':
            df[k].append(round(v['total']/3600,2))
        elif k == 'id':
            df['total_stops'].append(len(v.split('|'))-1)
        else:
            if k in df:
                df[k].append(v)

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#   cityFrom        cityTo cityCodeFrom cityCodeTo  price  duration  \
# 0   Sydney     Singapore          SYD        SIN    270      8.25
# 1   Sydney  Kuala Lumpur          SYD        KUL    292     22.25
# 2   Sydney   Phuket City          SYD        HKT    298     33.75
# 3   Sydney     Singapore          SYD        SIN    342     12.58
# 4   Sydney     Singapore          SYD        SIN    349     34.42
#
#    total_stops  distance           local_departure             local_arrival  \
# 0            0   6301.43  2022-04-01T13:25:00.000Z  2022-04-01T18:40:00.000Z
# 1            1   6591.75  2022-04-01T13:25:00.000Z  2022-04-02T08:40:00.000Z
# 2            1   7275.70  2022-04-01T13:25:00.000Z  2022-04-02T19:10:00.000Z
# 3            1   6301.43  2022-04-01T08:15:00.000Z  2022-04-01T17:50:00.000Z
# 4            1   6301.43  2022-04-01T20:30:00.000Z  2022-04-03T03:55:00.000Z
#
#                                            deep_link
# 0  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...
# 1  https://www.kiwi.com/deep?from=SYD&to=KUL&flig...
# 2  https://www.kiwi.com/deep?from=SYD&to=HKT&flig...
# 3  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...
# 4  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...

# %%
df['route'] = df.cityCodeFrom + "-" + df.cityCodeTo

# %%
df.head()
# Out:
#   cityFrom        cityTo cityCodeFrom cityCodeTo  price  duration  \
# 0   Sydney     Singapore          SYD        SIN    270      8.25
# 1   Sydney  Kuala Lumpur          SYD        KUL    292     22.25
# 2   Sydney   Phuket City          SYD        HKT    298     33.75
# 3   Sydney     Singapore          SYD        SIN    342     12.58
# 4   Sydney     Singapore          SYD        SIN    349     34.42
#
#    total_stops  distance           local_departure             local_arrival  \
# 0            0   6301.43  2022-04-01T13:25:00.000Z  2022-04-01T18:40:00.000Z
# 1            1   6591.75  2022-04-01T13:25:00.000Z  2022-04-02T08:40:00.000Z
# 2            1   7275.70  2022-04-01T13:25:00.000Z  2022-04-02T19:10:00.000Z
# 3            1   6301.43  2022-04-01T08:15:00.000Z  2022-04-01T17:50:00.000Z
# 4            1   6301.43  2022-04-01T20:30:00.000Z  2022-04-03T03:55:00.000Z
#
#                                            deep_link    route
# 0  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...  SYD-SIN
# 1  https://www.kiwi.com/deep?from=SYD&to=KUL&flig...  SYD-KUL
# 2  https://www.kiwi.com/deep?from=SYD&to=HKT&flig...  SYD-HKT
# 3  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...  SYD-SIN
# 4  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...  SYD-SIN

# %%
df = df.groupby('route').min().sort_values('cityTo')

# %%
df
# Out:
#         cityFrom        cityTo cityCodeFrom cityCodeTo  price  duration  \
# route
# SYD-DPS   Sydney      Denpasar          SYD        DPS    621     16.92
# TYO-DPS    Tokyo      Denpasar          TYO        DPS    487     22.33
# SYD-HAN   Sydney         Hanoi          SYD        HAN    389     18.00
# TYO-HAN    Tokyo         Hanoi          TYO        HAN    382      5.83
# SYD-KUL   Sydney  Kuala Lumpur          SYD        KUL    292      8.83
# TYO-KUL    Tokyo  Kuala Lumpur          TYO        KUL    470      7.42
# SYD-HKT   Sydney   Phuket City          SYD        HKT    298      9.50
# TYO-HKT    Tokyo   Phuket City          TYO        HKT    505      9.08
# SYD-SIN   Sydney     Singapore          SYD        SIN    270      8.25
# TYO-SIN    Tokyo     Singapore          TYO        SIN    423      7.25
#
#          total_stops  distance           local_departure  \
# route
# SYD-DPS            1   4627.24  2022-04-01T22:10:00.000Z
# TYO-DPS            1   5616.76  2022-04-01T21:10:00.000Z
# SYD-HAN            1   7798.15  2022-04-01T13:25:00.000Z
# TYO-HAN            0   3723.95  2022-04-01T09:15:00.000Z
# SYD-KUL            0   6591.75  2022-04-01T06:00:00.000Z
# TYO-KUL            0   5414.54  2022-04-01T07:00:00.000Z
# SYD-HKT            0   7275.70  2022-04-01T06:00:00.000Z
# TYO-HKT            1   5260.74  2022-04-01T12:00:00.000Z
# SYD-SIN            0   6301.43  2022-04-01T06:00:00.000Z
# TYO-SIN            0   5363.07  2022-04-01T10:20:00.000Z
#
#                     local_arrival  \
# route
# SYD-DPS  2022-04-02T12:05:00.000Z
# TYO-DPS  2022-04-02T18:50:00.000Z
# SYD-HAN  2022-04-02T11:25:00.000Z
# TYO-HAN  2022-04-01T13:35:00.000Z
# SYD-KUL  2022-04-01T15:35:00.000Z
# TYO-KUL  2022-04-01T16:45:00.000Z
# SYD-HKT  2022-04-01T16:30:00.000Z
# TYO-HKT  2022-04-01T19:05:00.000Z
# SYD-SIN  2022-04-01T14:15:00.000Z
# TYO-SIN  2022-04-02T00:10:00.000Z
#
#                                                  deep_link
# route
# SYD-DPS  https://www.kiwi.com/deep?from=SYD&to=DPS&flig...
# TYO-DPS  https://www.kiwi.com/deep?from=NRT&to=DPS&flig...
# SYD-HAN  https://www.kiwi.com/deep?from=SYD&to=HAN&flig...
# TYO-HAN  https://www.kiwi.com/deep?from=NRT&to=HAN&flig...
# SYD-KUL  https://www.kiwi.com/deep?from=SYD&to=KUL&flig...
# TYO-KUL  https://www.kiwi.com/deep?from=NRT&to=KUL&flig...
# SYD-HKT  https://www.kiwi.com/deep?from=SYD&to=HKT&flig...
# TYO-HKT  https://www.kiwi.com/deep?from=NRT&to=HKT&flig...
# SYD-SIN  https://www.kiwi.com/deep?from=SYD&to=SIN&flig...
# TYO-SIN  https://www.kiwi.com/deep?from=NRT&to=SIN&flig...

# %%
df = df.pivot(index='cityTo', columns='cityFrom', values=['price','duration','total_stops','distance','local_departure','local_arrival','deep_link'])

# %%
df['combined_price'] = df['price']['Sydney']+ df['price']['Tokyo']

# %%
df.sort_values(by='combined_price')
# Out:
#               price       duration        total_stops       distance           \
# cityFrom     Sydney Tokyo   Sydney  Tokyo      Sydney Tokyo   Sydney    Tokyo
# cityTo
# Singapore       270   423     8.25   7.25           0     0  6301.43  5363.07
# Kuala Lumpur    292   470     8.83   7.42           0     0  6591.75  5414.54
# Hanoi           389   382     18.0   5.83           1     0  7798.15  3723.95
# Phuket City     298   505      9.5   9.08           0     1   7275.7  5260.74
# Denpasar        621   487    16.92  22.33           1     1  4627.24  5616.76
#
#                        local_departure                            \
# cityFrom                        Sydney                     Tokyo
# cityTo
# Singapore     2022-04-01T06:00:00.000Z  2022-04-01T10:20:00.000Z
# Kuala Lumpur  2022-04-01T06:00:00.000Z  2022-04-01T07:00:00.000Z
# Hanoi         2022-04-01T13:25:00.000Z  2022-04-01T09:15:00.000Z
# Phuket City   2022-04-01T06:00:00.000Z  2022-04-01T12:00:00.000Z
# Denpasar      2022-04-01T22:10:00.000Z  2022-04-01T21:10:00.000Z
#
#                          local_arrival                            \
# cityFrom                        Sydney                     Tokyo
# cityTo
# Singapore     2022-04-01T14:15:00.000Z  2022-04-02T00:10:00.000Z
# Kuala Lumpur  2022-04-01T15:35:00.000Z  2022-04-01T16:45:00.000Z
# Hanoi         2022-04-02T11:25:00.000Z  2022-04-01T13:35:00.000Z
# Phuket City   2022-04-01T16:30:00.000Z  2022-04-01T19:05:00.000Z
# Denpasar      2022-04-02T12:05:00.000Z  2022-04-02T18:50:00.000Z
#
#                                                       deep_link  \
# cityFrom                                                 Sydney
# cityTo
# Singapore     https://www.kiwi.com/deep?from=SYD&to=SIN&flig...
# Kuala Lumpur  https://www.kiwi.com/deep?from=SYD&to=KUL&flig...
# Hanoi         https://www.kiwi.com/deep?from=SYD&to=HAN&flig...
# Phuket City   https://www.kiwi.com/deep?from=SYD&to=HKT&flig...
# Denpasar      https://www.kiwi.com/deep?from=SYD&to=DPS&flig...
#
#                                                                 combined_price
# cityFrom                                                  Tokyo
# cityTo
# Singapore     https://www.kiwi.com/deep?from=NRT&to=SIN&flig...            693
# Kuala Lumpur  https://www.kiwi.com/deep?from=NRT&to=KUL&flig...            762
# Hanoi         https://www.kiwi.com/deep?from=NRT&to=HAN&flig...            771
# Phuket City   https://www.kiwi.com/deep?from=NRT&to=HKT&flig...            803
# Denpasar      https://www.kiwi.com/deep?from=NRT&to=DPS&flig...           1108

# %%
df.shape
# Out:
# (5, 7)

# %%
airports = pd.read_csv('../raw_data/airport_codes.csv')

# %%
airports.head()
# Out:
#                                            city_name  \
# 0                          Aalborg - Aalborg Airport
# 1    Albuquerque - Albuquerque International Sunport
# 2       Abuja - Nnamdi Azikiwe International Airport
# 3                   Aberdeen - Aberdeen Dyce Airport
# 4  Acapulco - General Juan N Alvarez Internationa...
#
#                                            name  Unnamed: 2 continent  \
# 0                               Aalborg Airport         NaN        EU
# 1             Albuquerque International Sunport         NaN       NaN
# 2          Nnamdi Azikiwe International Airport         NaN        AF
# 3                         Aberdeen Dyce Airport         NaN        EU
# 4  General Juan N Alvarez International Airport         NaN       NaN
#
#   iso_country iso_region municipality gps_code iata_code        lat  \
# 0          DK      DK-81      Aalborg     EKYT       AAL  57.092759
# 1          US      US-NM  Albuquerque     KABQ       ABQ  35.040199
# 2          NG      NG-FC        Abuja     DNAA       ABV   9.006790
# 3          GB     GB-SCT     Aberdeen     EGPD       ABZ  57.201900
# 4          MX     MX-GRO     Acapulco     MMAA       ACA  16.757099
#
#           lon  elevation_ft ident
# 0    9.849243          10.0  EKYT
# 1 -106.609001        5355.0  KABQ
# 2    7.263170        1123.0  DNAA
# 3   -2.197780         215.0  EGPD
# 4  -99.753998          16.0  MMAA

# %%
airports['continent'].value_counts()
# Out:
# EU    157
# AS    156
# AF     48
# SA     21
# OC     13
# Name: continent, dtype: int64

# %%
asian_codes = airports[airports['continent']=='AS']['iata_code'].dropna()

# %%
type(asian_codes)
# Out:
# pandas.core.series.Series

# %%
asian_codes
# Out:
# 6      ADA
# 7      ADB
# 17     ALA
# 20     ALP
# 22     AMM
#       ...
# 536    VDA
# 548    WNZ
# 550    WUH
# 551    XIY
# 552    XMN
# Name: iata_code, Length: 153, dtype: object

# %%
my_list = []
for code in asian_codes:
    my_list.append(code)

# %%
'NRT' in my_list
# Out:
# True

# %%
my_list.remove('NRT')

# %%
check_list = ','.join(my_list)

# %%
url = "https://tequila-api.kiwi.com/v2/search"
headers = CaseInsensitiveDict()

  

query_string = {'fly_from':'NRT,SYD', 'fly_to':check_list,
                'date_from':'01/04/2022', 'date_to':'01/04/2022','return_from':'','return_to':'', 
               'adults':1, 'children':0,'selected_cabins':'M','adult_hold_bag':1,'adult_hand_bag':1,
               "curr":'USD', 'limit':1000}

headers["accept"] = "application/json"
headers["apikey"] = "Ul0VynVifRdwPUGTkFU_Btfro1vyewb7"


resp2 = requests.get(url, headers=headers, params=query_string)

print(resp2.status_code)
# Out:
# 200

# %%
len(resp2.json()['data'])
# Out:
# 756
