# %%
from smackbang.matches import get_matches
import pandas as pd
# %load_ext autoreload
# %autoreload 2

# %%
df = get_matches(origin_one='NRT',origin_two='SYD',departure_date='01/04/2022')

# %%
df
# Out:
#                   price       duration        total_stops        distance  \
# cityFrom         Sydney Tokyo   Sydney  Tokyo      Sydney Tokyo    Sydney
# cityTo
# Bangkok             350   441     9.83    6.5           0     0   7523.15
# Osaka               739    80    12.33    1.5           1     0   7824.93
# Fukuoka             738    82    13.08   2.08           1     0   7823.25
# Hanoi               387   439     18.0   6.33           1     0   7798.15
# Phuket City         325   503      9.5   9.08           0     1    7275.7
# Kuala Lumpur        290   540     8.83  14.67           0     1   6591.75
# Taipei              454   377    21.08   3.67           1     0   7293.46
# Nagoya              755   104    23.33   1.25           1     0   7804.21
# Singapore           269   610     8.25   7.25           0     0   6301.43
# Ho Chi Minh City    453   442     8.92   9.08           0     1   6853.68
# Seoul               696   277    22.67    2.5           1     0   8351.95
# ...

# %%
airports = pd.read_csv('../raw_data/airport_codes.csv')

# %%
airports
# Out:
#                                              city_name  \
# 0                            Aalborg - Aalborg Airport
# 1      Albuquerque - Albuquerque International Sunport
# 2         Abuja - Nnamdi Azikiwe International Airport
# 3                     Aberdeen - Aberdeen Dyce Airport
# 4    Acapulco - General Juan N Alvarez Internationa...
# ..                                                 ...
# 568    Samarinda - Sungai Siring International Airport
# 569    Lal-lo - Northern Cagayan International Airport
# 570                          Tarsus - Çukurova Airport
# 571                                              - atl
# 572                    Kazan - Borisoglebskoye Airport
#
#                                              name  Unnamed: 2 continent  \
# 0                                 Aalborg Airport         NaN        EU
# 1               Albuquerque International Sunport         NaN       NaN
# 2            Nnamdi Azikiwe International Airport         NaN        AF
# ...

# %%
'Da Nang' in list(airports['municipality'])
# Out:
# True
